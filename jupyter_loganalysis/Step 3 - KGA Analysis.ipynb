# %%
# Graph Data
from py2neo import Graph

# %%
# set up authentication parameters
graph = Graph(password="admin")

# %%
q1 = '"DC1.insecurebank.local"'
q2 = 4742
qR = ""
result = graph.run(
    f"MATCH (a)-[r]->(h) \
    RETURN a.label "
).to_table()
result

# cypherlang take
# Out:
#  a.label
# -----------------
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
#  LAPTOP-JU4M3I0E
# ...
