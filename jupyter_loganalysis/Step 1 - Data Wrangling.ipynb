# %% [markdown]
# # Log parser and preprocessing
# Currently takes in .evtx files.

# %%
from evtx import PyEvtxParser
import json
from pprint import pprint
import glob

# Visualisation
import networkx as nx
from pyvis.network import Network
from nested_lookup import nested_lookup, get_all_keys

# %%
# Declare directories
inputDir = ".\\sample_dataset\\input\\"
outputDir = ".\\sample_dataset\\output\\"

logextension = ".evtx"

outputfile_json = outputDir + "preprocessed.json"

# %%
# Get file list in the directory
inputfilelist = glob.glob(inputDir + "*" + logextension)
inputfilelist
# Out:
# ['.\\sample_dataset\\input\\4794_DSRM_password_change_t1098.evtx',
#  '.\\sample_dataset\\input\\ACL_ForcePwd_SPNAdd_User_Computer_Accounts.evtx',
#  '.\\sample_dataset\\input\\babyshark_mimikatz_powershell.evtx',
#  '.\\sample_dataset\\input\\CA_4624_4625_LogonType2_LogonProc_chrome.evtx',
#  '.\\sample_dataset\\input\\CA_chrome_firefox_opera_4663.evtx',
#  '.\\sample_dataset\\input\\CA_DCSync_4662.evtx',
#  '.\\sample_dataset\\input\\CA_hashdump_4663_4656_lsass_access.evtx',
#  '.\\sample_dataset\\input\\CA_keefarce_keepass_credump.evtx',
#  '.\\sample_dataset\\input\\CA_keepass_KeeThief_Get-KeePassDatabaseKey.evtx',
#  '.\\sample_dataset\\input\\CA_Mimikatz_Memssp_Default_Logs_Sysmon_11.evtx',
#  '.\\sample_dataset\\input\\CA_protectedstorage_5145_rpc_masterkey.evtx',
#  '.\\sample_dataset\\input\\CA_sysmon_hashdump_cmd_meterpreter.evtx',
#  '.\\sample_dataset\\input\\CA_teamviewer-dumper_sysmon_10.evtx',
#  '.\\sample_dataset\\input\\dc_applog_ntdsutil_dfir_325_326_327.evtx',
#  '.\\sample_dataset\\input\\discovery_sysmon_1_iis_pwd_and_config_discovery_appcmd.evtx',
#  '.\\sample_dataset\\input\\etw_rpc_zerologon.evtx',
#  '.\\sample_dataset\\input\\kerberos_pwd_spray_4771.evtx',
#  '.\\sample_dataset\\input\\MSSQL_multiple_failed_logon_EventID_18456.evtx',
#  '.\\sample_dataset\\input\\phish_windows_credentials_powershell_scriptblockLog_4104.evtx',
#  '.\\sample_dataset\\input\\Powershell_4104_MiniDumpWriteDump_Lsass.evtx',
#  '.\\sample_dataset\\input\\remote_pwd_reset_rpc_mimikatz_postzerologon_target_DC.evtx',
#  '.\\sample_dataset\\input\\Sysmon13_MachineAccount_Password_Hash_Changed_via_LsarSetSecret.evtx',
#  '.\\sample_dataset\\input\\sysmon17_18_kekeo_tsssp_default_np.evtx',
#  '.\\sample_dataset\\input\\sysmon_10_11_lsass_memdump.evtx',
#  '.\\sample_dataset\\input\\sysmon_10_11_outlfank_dumpert_and_andrewspecial_memdump.evtx',
#  '.\\sample_dataset\\input\\sysmon_10_1_memdump_comsvcs_minidump.evtx',
#  '.\\sample_dataset\\input\\sysmon_10_lsass_mimikatz_sekurlsa_logonpasswords.evtx',
#  '.\\sample_dataset\\input\\sysmon_13_keylogger_directx.evtx',
#  '.\\sample_dataset\\input\\Sysmon_13_Local_Admin_Password_Changed.evtx',
#  '.\\sample_dataset\\input\\sysmon_2x10_lsass_with_different_pid_RtlCreateProcessReflection.evtx',
#  '.\\sample_dataset\\input\\sysmon_3_10_Invoke-Mimikatz_hosted_Github.evtx',
#  '.\\sample_dataset\\input\\sysmon_rdrleakdiag_lsass_dump.evtx',
#  '.\\sample_dataset\\input\\Zerologon_CVE-2020-1472_DFIR_System_NetLogon_Error_EventID_5805.evtx',
#  '.\\sample_dataset\\input\\Zerologon_VoidSec_CVE-2020-1472_4626_LT3_Anonym_follwedby_4742_DC_Anony_DC.evtx']

# %%
sample = json.loads(list(PyEvtxParser(inputfilelist[5]).records_json())[0]["data"])
pprint(sample)
# Out:
# {'Event': {'#attributes': {'xmlns': 'http://schemas.microsoft.com/win/2004/08/events/event'},
#            'EventData': {'AccessList': '%%7688\r\n\t\t\t\t',
#                          'AccessMask': '0x100',
#                          'AdditionalInfo': '-',
#                          'AdditionalInfo2': '',
#                          'HandleId': '0x0',
#                          'ObjectName': '%{c6faf700-bfe4-452a-a766-424f84c29583}',
#                          'ObjectServer': 'DS',
#                          'ObjectType': '%{19195a5b-6da0-11d0-afd3-00c04fd930c9}',
#                          'OperationType': 'Object Access',
#                          'Properties': '%%7688\r\n'
#                                        '\t\t'
#                                        '{1131f6ad-9c07-11d1-f79f-00c04fc2dcd2}\r\n'
#                                        '\t'
#                                        '{19195a5b-6da0-11d0-afd3-00c04fd930c9}\r\n',
#                          'SubjectDomainName': 'insecurebank',
#                          'SubjectLogonId': '0x40c6511',
#                          'SubjectUserName': 'Administrator',
#                          'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-500'},
#            'System': {'Channel': 'Security',
#                       'Computer': 'DC1.insecurebank.local',
#                       'Correlation': None,
#                       'EventID': 4662,
#                       'EventRecordID': 202793,
#                       'Execution': {'#attributes': {'ProcessID': 444,
#                                                     'ThreadID': 4632}},
#                       'Keywords': '0x8020000000000000',
#                       'Level': 0,
#                       'Opcode': 0,
#                       'Provider': {'#attributes': {'Guid': '54849625-5478-4994-A5BA-3E3B0328C30D',
#                                                    'Name': 'Microsoft-Windows-Security-Auditing'}},
#                       'Security': None,
#                       'Task': 14080,
#                       'TimeCreated': {'#attributes': {'SystemTime': '2019-05-08T02:10:43.487217Z'}},
#                       'Version': 0}}}

# %%
# Bulk process and write to output directory
jsonlist= []

for filepath in inputfilelist:
    parser = PyEvtxParser(filepath)
    
    for record in parser.records_json():
        dictdata = record["data"]
        
        '''<<TODO: data sanitizer function'''
            
        jsondata = json.loads(dictdata)
        jsonlist.append(jsondata)
        
with open(outputfile_json, 'w') as filewriter:
    json.dump(jsonlist,filewriter)

# %%
"""Extract nested values from a JSON tree."""
def json_extract(obj, key):
    """Recursively fetch values from nested JSON."""
    arr = []

    def extract(obj, arr, key):
        """Recursively search for values of key in JSON tree."""
        if isinstance(obj, dict):
            for k, v in obj.items():
                if isinstance(v, (dict, list)):
                    extract(v, arr, key)
                elif k == key:
                    arr.append(v)
        elif isinstance(obj, list):
            for item in obj:
                extract(item, arr, key)
        return arr

    values = extract(obj, arr, key)

    if len(values) == 1:
        return values[0]
    else:
        return values

# %%
#Load event transformer lookup file to dict
f = open('./transformer_lookup.json',) 
eventdict = json.load(f)

def logtransform(logdict, **kwargs):
    logXformedlist = []
    
    if "eventid" in kwargs:
        #transform selected eventid in the log(for debug)
        eventidsel = kwargs.get("eventid")
        for item in logdict:
            if eventidsel in nested_lookup("EventID", item):
                evtTransformDict = {}
                for prop in eventdict[str(eventidsel)]:
                    evtTransformDict[prop] = json_extract(item, prop)
                logXformedlist.append(evtTransformDict)
    else:
    
        #loop through logs, find eventid, match against lookup, transform
        for item in logdict:
            eventid = str(nested_lookup("EventID", item)[0]) #get eventid in str
            evtTransformDict = {}
            if eventid in eventdict.keys():
                for prop in eventdict[eventid]:
                    evtTransformDict[prop] = json_extract(item, prop)
                logXformedlist.append(evtTransformDict)
    
    return logXformedlist

jsonlist = logtransform(jsonlist)
jsonlist
# Out:
# [{'EventID': 5136,
#   'SystemTime': '2019-03-25T12:33:44.816657Z',
#   'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-1108',
#   'SubjectUserName': 'bob',
#   'SubjectDomainName': 'insecurebank',
#   'SubjectLogonId': '0x8d7099',
#   'OpCorrelationID': '7A0DDD82-407E-41DA-83B1-014A84297AB8',
#   'AppCorrelationID': '-',
#   'DSName': 'insecurebank.local',
#   'DSType': '%%14676',
#   'ObjectDN': 'CN={6AC1786C-016F-11D2-945F-00C04FB984F9},CN=POLICIES,CN=SYSTEM,DC=INSECUREBANK,DC=LOCAL',
#   'ObjectClass': 'groupPolicyContainer',
#   'AttributeLDAPDisplayName': 'versionNumber',
#   'AttributeSyntaxOID': '2.5.5.9',
#   'AttributeValue': '9',
#   'OperationType': '%%14674'},
#  {'EventID': 5136,
#   'SystemTime': '2019-03-25T12:33:44.816657Z',
#   'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-1108',
#   'SubjectUserName': 'bob',
#   'SubjectDomainName': 'insecurebank',
#   'SubjectLogonId': '0x8d7099',
#   'OpCorrelationID': '7A0DDD82-407E-41DA-83B1-014A84297AB8',
#   'AppCorrelationID': '-',
#   'DSName': 'insecurebank.local',
#   'DSType': '%%14676',
#   'ObjectDN': 'CN={6AC1786C-016F-11D2-945F-00C04FB984F9},CN=POLICIES,CN=SYSTEM,DC=INSECUREBANK,DC=LOCAL',
#   'ObjectClass': 'groupPolicyContainer',
#   'AttributeLDAPDisplayName': 'versionNumber',
#   'AttributeSyntaxOID': '2.5.5.9',
#   'AttributeValue': '8',
#   'OperationType': '%%14675'},
#  {'EventID': 5136,
#   'SystemTime': '2019-03-25T12:33:44.816657Z',
#   'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-1108',
#   'SubjectUserName': 'bob',
#   'SubjectDomainName': 'insecurebank',
#   'SubjectLogonId': '0x8d7099',
#   'OpCorrelationID': '9BA86D72-7C57-4A9D-8239-E93D9AC25584',
#   'AppCorrelationID': '-',
#   'DSName': 'insecurebank.local',
#   'DSType': '%%14676',
#   'ObjectDN': 'CN={6AC1786C-016F-11D2-945F-00C04FB984F9},CN=POLICIES,CN=SYSTEM,DC=INSECUREBANK,DC=LOCAL',
#   'ObjectClass': 'groupPolicyContainer',
#   'AttributeLDAPDisplayName': 'versionNumber',
#   'AttributeSyntaxOID': '2.5.5.9',
#   'AttributeValue': '8',
#   'OperationType': '%%14674'},
#  {'EventID': 5136,
#   'SystemTime': '2019-03-25T12:33:44.816657Z',
#   'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-1108',
#   'SubjectUserName': 'bob',
#   'SubjectDomainName': 'insecurebank',
#   'SubjectLogonId': '0x8d7099',
#   'OpCorrelationID': '9BA86D72-7C57-4A9D-8239-E93D9AC25584',
#   'AppCorrelationID': '-',
#   'DSName': 'insecurebank.local',
#   'DSType': '%%14676',
#   'ObjectDN': 'CN={6AC1786C-016F-11D2-945F-00C04FB984F9},CN=POLICIES,CN=SYSTEM,DC=INSECUREBANK,DC=LOCAL',
#   'ObjectClass': 'groupPolicyContainer',
#   'AttributeLDAPDisplayName': 'versionNumber',
#   'AttributeSyntaxOID': '2.5.5.9',
#   'AttributeValue': '7',
#   'OperationType': '%%14675'},
#  {'EventID': 5136,
#   'SystemTime': '2019-03-25T12:31:44.810605Z',
#   'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-1108',
#   'SubjectUserName': 'bob',
#   'SubjectDomainName': 'insecurebank',
#   'SubjectLogonId': '0x8d7099',
#   'OpCorrelationID': '49A1E957-0B53-4119-9013-9BD2E846A68E',
#   'AppCorrelationID': '-',
#   'DSName': 'insecurebank.local',
#   'DSType': '%%14676',
#   'ObjectDN': 'CN={31B2F340-016D-11D2-945F-00C04FB984F9},CN=POLICIES,CN=SYSTEM,DC=INSECUREBANK,DC=LOCAL',
#   'ObjectClass': 'groupPolicyContainer',
#   'AttributeLDAPDisplayName': 'versionNumber',
#   'AttributeSyntaxOID': '2.5.5.9',
#   'AttributeValue': '65561',
#   'OperationType': '%%14674'},
#  {'EventID': 5136,
#   'SystemTime': '2019-03-25T12:31:44.810605Z',
#   'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-1108',
#   'SubjectUserName': 'bob',
#   'SubjectDomainName': 'insecurebank',
#   'SubjectLogonId': '0x8d7099',
#   'OpCorrelationID': '49A1E957-0B53-4119-9013-9BD2E846A68E',
#   'AppCorrelationID': '-',
#   'DSName': 'insecurebank.local',
#   'DSType': '%%14676',
#   'ObjectDN': 'CN={31B2F340-016D-11D2-945F-00C04FB984F9},CN=POLICIES,CN=SYSTEM,DC=INSECUREBANK,DC=LOCAL',
#   'ObjectClass': 'groupPolicyContainer',
#   'AttributeLDAPDisplayName': 'versionNumber',
#   'AttributeSyntaxOID': '2.5.5.9',
#   'AttributeValue': '65560',
#   'OperationType': '%%14675'},
#  {'EventID': 5136,
#   'SystemTime': '2019-03-25T11:19:10.770608Z',
#   'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-1108',
#   'SubjectUserName': 'bob',
#   'SubjectDomainName': 'insecurebank',
#   'SubjectLogonId': '0x8d7099',
#   'OpCorrelationID': '91DBE69C-C6D0-4457-A39A-EBA1400E7813',
#   'AppCorrelationID': '-',
#   'DSName': 'insecurebank.local',
#   'DSType': '%%14676',
#   'ObjectDN': 'CN={31B2F340-016D-11D2-945F-00C04FB984F9},CN=POLICIES,CN=SYSTEM,DC=INSECUREBANK,DC=LOCAL',
#   'ObjectClass': 'groupPolicyContainer',
#   'AttributeLDAPDisplayName': 'versionNumber',
#   'AttributeSyntaxOID': '2.5.5.9',
#   'AttributeValue': '65560',
#   'OperationType': '%%14674'},
#  {'EventID': 5136,
#   'SystemTime': '2019-03-25T11:19:10.770608Z',
#   'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-1108',
#   'SubjectUserName': 'bob',
#   'SubjectDomainName': 'insecurebank',
#   'SubjectLogonId': '0x8d7099',
#   'OpCorrelationID': '91DBE69C-C6D0-4457-A39A-EBA1400E7813',
#   'AppCorrelationID': '-',
#   'DSName': 'insecurebank.local',
#   'DSType': '%%14676',
#   'ObjectDN': 'CN={31B2F340-016D-11D2-945F-00C04FB984F9},CN=POLICIES,CN=SYSTEM,DC=INSECUREBANK,DC=LOCAL',
#   'ObjectClass': 'groupPolicyContainer',
#   'AttributeLDAPDisplayName': 'versionNumber',
#   'AttributeSyntaxOID': '2.5.5.9',
#   'AttributeValue': '65559',
#   'OperationType': '%%14675'},
#  {'EventID': 5136,
#   'SystemTime': '2019-03-25T11:18:40.768634Z',
#   'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-1108',
#   'SubjectUserName': 'bob',
#   'SubjectDomainName': 'insecurebank',
#   'SubjectLogonId': '0x8d7099',
#   'OpCorrelationID': 'B5A111CF-BE68-4C60-9412-E0C6777D4522',
#   'AppCorrelationID': '-',
#   'DSName': 'insecurebank.local',
#   'DSType': '%%14676',
#   'ObjectDN': 'CN={31B2F340-016D-11D2-945F-00C04FB984F9},CN=POLICIES,CN=SYSTEM,DC=INSECUREBANK,DC=LOCAL',
#   'ObjectClass': 'groupPolicyContainer',
#   'AttributeLDAPDisplayName': 'versionNumber',
#   'AttributeSyntaxOID': '2.5.5.9',
#   'AttributeValue': '65559',
#   'OperationType': '%%14674'},
#  {'EventID': 5136,
#   'SystemTime': '2019-03-25T11:18:40.768634Z',
#   'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-1108',
#   'SubjectUserName': 'bob',
#   'SubjectDomainName': 'insecurebank',
#   'SubjectLogonId': '0x8d7099',
#   'OpCorrelationID': 'B5A111CF-BE68-4C60-9412-E0C6777D4522',
#   'AppCorrelationID': '-',
#   'DSName': 'insecurebank.local',
#   'DSType': '%%14676',
#   'ObjectDN': 'CN={31B2F340-016D-11D2-945F-00C04FB984F9},CN=POLICIES,CN=SYSTEM,DC=INSECUREBANK,DC=LOCAL',
#   'ObjectClass': 'groupPolicyContainer',
#   'AttributeLDAPDisplayName': 'versionNumber',
#   'AttributeSyntaxOID': '2.5.5.9',
#   'AttributeValue': '65558',
#   'OperationType': '%%14675'},
#  {'EventID': 5136,
#   'SystemTime': '2019-03-25T11:14:43.566644Z',
#   'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-1108',
#   'SubjectUserName': 'bob',
#   'SubjectDomainName': 'insecurebank',
#   'SubjectLogonId': '0x8d7099',
#   'OpCorrelationID': '4396B334-2A04-4CFF-A90E-4C079E35265B',
#   'AppCorrelationID': '-',
#   'DSName': 'insecurebank.local',
#   'DSType': '%%14676',
#   'ObjectDN': 'CN={31B2F340-016D-11D2-945F-00C04FB984F9},CN=POLICIES,CN=SYSTEM,DC=INSECUREBANK,DC=LOCAL',
#   'ObjectClass': 'groupPolicyContainer',
#   'AttributeLDAPDisplayName': 'versionNumber',
#   'AttributeSyntaxOID': '2.5.5.9',
#   'AttributeValue': '65558',
#   'OperationType': '%%14674'},
#  {'EventID': 5136,
#   'SystemTime': '2019-03-25T11:14:43.566644Z',
#   'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-1108',
#   'SubjectUserName': 'bob',
#   'SubjectDomainName': 'insecurebank',
#   'SubjectLogonId': '0x8d7099',
#   'OpCorrelationID': '4396B334-2A04-4CFF-A90E-4C079E35265B',
#   'AppCorrelationID': '-',
#   'DSName': 'insecurebank.local',
#   'DSType': '%%14676',
#   'ObjectDN': 'CN={31B2F340-016D-11D2-945F-00C04FB984F9},CN=POLICIES,CN=SYSTEM,DC=INSECUREBANK,DC=LOCAL',
#   'ObjectClass': 'groupPolicyContainer',
#   'AttributeLDAPDisplayName': 'versionNumber',
#   'AttributeSyntaxOID': '2.5.5.9',
#   'AttributeValue': '65557',
#   'OperationType': '%%14675'},
#  {'EventID': 5136,
#   'SystemTime': '2019-03-25T11:14:43.566644Z',
#   'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-1108',
#   'SubjectUserName': 'bob',
#   'SubjectDomainName': 'insecurebank',
#   'SubjectLogonId': '0x8d7099',
#   'OpCorrelationID': '5D540F5D-9734-41FB-865C-6BA6EF4269E4',
#   'AppCorrelationID': '-',
#   'DSName': 'insecurebank.local',
#   'DSType': '%%14676',
#   'ObjectDN': 'CN={31B2F340-016D-11D2-945F-00C04FB984F9},CN=POLICIES,CN=SYSTEM,DC=INSECUREBANK,DC=LOCAL',
#   'ObjectClass': 'groupPolicyContainer',
#   'AttributeLDAPDisplayName': 'versionNumber',
#   'AttributeSyntaxOID': '2.5.5.9',
#   'AttributeValue': '65557',
#   'OperationType': '%%14674'},
#  {'EventID': 5136,
#   'SystemTime': '2019-03-25T11:14:43.566644Z',
#   'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-1108',
#   'SubjectUserName': 'bob',
#   'SubjectDomainName': 'insecurebank',
#   'SubjectLogonId': '0x8d7099',
#   'OpCorrelationID': '5D540F5D-9734-41FB-865C-6BA6EF4269E4',
#   'AppCorrelationID': '-',
#   'DSName': 'insecurebank.local',
#   'DSType': '%%14676',
#   'ObjectDN': 'CN={31B2F340-016D-11D2-945F-00C04FB984F9},CN=POLICIES,CN=SYSTEM,DC=INSECUREBANK,DC=LOCAL',
#   'ObjectClass': 'groupPolicyContainer',
#   'AttributeLDAPDisplayName': 'versionNumber',
#   'AttributeSyntaxOID': '2.5.5.9',
#   'AttributeValue': '65556',
#   'OperationType': '%%14675'},
#  {'EventID': 5136,
#   'SystemTime': '2019-03-25T10:35:36.463626Z',
#   'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-1108',
#   'SubjectUserName': 'bob',
#   'SubjectDomainName': 'insecurebank',
#   'SubjectLogonId': '0x8d7099',
#   'OpCorrelationID': 'B48B013C-1D7B-4192-9185-EFC882C4947A',
#   'AppCorrelationID': '-',
#   'DSName': 'insecurebank.local',
#   'DSType': '%%14676',
#   'ObjectDN': 'CN={31B2F340-016D-11D2-945F-00C04FB984F9},CN=POLICIES,CN=SYSTEM,DC=INSECUREBANK,DC=LOCAL',
#   'ObjectClass': 'groupPolicyContainer',
#   'AttributeLDAPDisplayName': 'versionNumber',
#   'AttributeSyntaxOID': '2.5.5.9',
#   'AttributeValue': '65556',
#   'OperationType': '%%14674'},
#  {'EventID': 5136,
#   'SystemTime': '2019-03-25T10:35:36.463626Z',
#   'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-1108',
#   'SubjectUserName': 'bob',
#   'SubjectDomainName': 'insecurebank',
#   'SubjectLogonId': '0x8d7099',
#   'OpCorrelationID': 'B48B013C-1D7B-4192-9185-EFC882C4947A',
#   'AppCorrelationID': '-',
#   'DSName': 'insecurebank.local',
#   'DSType': '%%14676',
#   'ObjectDN': 'CN={31B2F340-016D-11D2-945F-00C04FB984F9},CN=POLICIES,CN=SYSTEM,DC=INSECUREBANK,DC=LOCAL',
#   'ObjectClass': 'groupPolicyContainer',
#   'AttributeLDAPDisplayName': 'versionNumber',
#   'AttributeSyntaxOID': '2.5.5.9',
#   'AttributeValue': '65555',
#   'OperationType': '%%14675'},
#  {'EventID': 5136,
#   'SystemTime': '2019-03-25T10:35:16.462616Z',
#   'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-1108',
#   'SubjectUserName': 'bob',
#   'SubjectDomainName': 'insecurebank',
#   'SubjectLogonId': '0x8d7099',
#   'OpCorrelationID': '6548DB79-3AD6-41E2-A3BB-C3506A86B579',
#   'AppCorrelationID': '-',
#   'DSName': 'insecurebank.local',
#   'DSType': '%%14676',
#   'ObjectDN': 'CN={31B2F340-016D-11D2-945F-00C04FB984F9},CN=POLICIES,CN=SYSTEM,DC=INSECUREBANK,DC=LOCAL',
#   'ObjectClass': 'groupPolicyContainer',
#   'AttributeLDAPDisplayName': 'versionNumber',
#   'AttributeSyntaxOID': '2.5.5.9',
#   'AttributeValue': '65555',
#   'OperationType': '%%14674'},
#  {'EventID': 5136,
#   'SystemTime': '2019-03-25T10:35:16.462616Z',
#   'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-1108',
#   'SubjectUserName': 'bob',
#   'SubjectDomainName': 'insecurebank',
#   'SubjectLogonId': '0x8d7099',
#   'OpCorrelationID': '6548DB79-3AD6-41E2-A3BB-C3506A86B579',
#   'AppCorrelationID': '-',
#   'DSName': 'insecurebank.local',
#   'DSType': '%%14676',
#   'ObjectDN': 'CN={31B2F340-016D-11D2-945F-00C04FB984F9},CN=POLICIES,CN=SYSTEM,DC=INSECUREBANK,DC=LOCAL',
#   'ObjectClass': 'groupPolicyContainer',
#   'AttributeLDAPDisplayName': 'versionNumber',
#   'AttributeSyntaxOID': '2.5.5.9',
#   'AttributeValue': '65554',
#   'OperationType': '%%14675'},
#  {'EventID': 5136,
#   'SystemTime': '2019-03-25T10:34:16.458631Z',
#   'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-1108',
#   'SubjectUserName': 'bob',
#   'SubjectDomainName': 'insecurebank',
#   'SubjectLogonId': '0x8d7099',
#   'OpCorrelationID': '4929664A-5CD8-4C73-BF19-223ACA5501F3',
#   'AppCorrelationID': '-',
#   'DSName': 'insecurebank.local',
#   'DSType': '%%14676',
#   'ObjectDN': 'CN={6AC1786C-016F-11D2-945F-00C04FB984F9},CN=POLICIES,CN=SYSTEM,DC=INSECUREBANK,DC=LOCAL',
#   'ObjectClass': 'groupPolicyContainer',
#   'AttributeLDAPDisplayName': 'versionNumber',
#   'AttributeSyntaxOID': '2.5.5.9',
#   'AttributeValue': '7',
#   'OperationType': '%%14674'},
#  {'EventID': 5136,
#   'SystemTime': '2019-03-25T10:34:16.458631Z',
#   'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-1108',
#   'SubjectUserName': 'bob',
#   'SubjectDomainName': 'insecurebank',
#   'SubjectLogonId': '0x8d7099',
#   'OpCorrelationID': '4929664A-5CD8-4C73-BF19-223ACA5501F3',
#   'AppCorrelationID': '-',
#   'DSName': 'insecurebank.local',
#   'DSType': '%%14676',
#   'ObjectDN': 'CN={6AC1786C-016F-11D2-945F-00C04FB984F9},CN=POLICIES,CN=SYSTEM,DC=INSECUREBANK,DC=LOCAL',
#   'ObjectClass': 'groupPolicyContainer',
#   'AttributeLDAPDisplayName': 'versionNumber',
#   'AttributeSyntaxOID': '2.5.5.9',
#   'AttributeValue': '6',
#   'OperationType': '%%14675'},
#  {'EventID': 5136,
#   'SystemTime': '2019-03-25T10:33:56.457629Z',
#   'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-1108',
#   'SubjectUserName': 'bob',
#   'SubjectDomainName': 'insecurebank',
#   'SubjectLogonId': '0x8d7099',
#   'OpCorrelationID': '780EA6E1-6307-48D6-8B0D-8C45CC7534AE',
#   'AppCorrelationID': '-',
#   'DSName': 'insecurebank.local',
#   'DSType': '%%14676',
#   'ObjectDN': 'CN={6AC1786C-016F-11D2-945F-00C04FB984F9},CN=POLICIES,CN=SYSTEM,DC=INSECUREBANK,DC=LOCAL',
#   'ObjectClass': 'groupPolicyContainer',
#   'AttributeLDAPDisplayName': 'versionNumber',
#   'AttributeSyntaxOID': '2.5.5.9',
#   'AttributeValue': '6',
#   'OperationType': '%%14674'},
#  {'EventID': 5136,
#   'SystemTime': '2019-03-25T10:33:56.457629Z',
#   'SubjectUserSid': 'S-1-5-21-738609754-2819869699-4189121830-1108',
#   'SubjectUserName': 'bob',
#   'SubjectDomainName': 'insecurebank',
#   'SubjectLogonId': '0x8d7099',
#   'OpCorrelationID': '780EA6E1-6307-48D6-8B0D-8C45CC7534AE',
#   'AppCorrelationID': '-',
#   'DSName': 'insecurebank.local',
#   'DSType': '%%14676',
#   'ObjectDN': 'CN={6AC1786C-016F-11D2-945F-00C04FB984F9},CN=POLICIES,CN=SYSTEM,DC=INSECUREBANK,DC=LOCAL',
#   'ObjectClass': 'groupPolicyContainer',
#   'AttributeLDAPDisplayName': 'versionNumber',
#   'AttributeSyntaxOID': '2.5.5.9',
#   'AttributeValue': '5',
#   'OperationType': '%%14675'},
#  {'EventID': 11,
#   'SystemTime': '2019-04-18T17:03:03.441979Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'ProcessGuid': '365ABB72-AB28-5CB8-0000-0010F2E20000',
#   'ProcessId': 1388,
#   'TargetFilename': 'C:\\Users\\IEUser\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\HTools (vboxsrv) (D).lnk',
#   'Image': 'C:\\Windows\\Explorer.EXE',
#   'CreationUtcTime': '2019-04-18 17:03:03.441'},
#  {'EventID': 11,
#   'SystemTime': '2019-04-18T17:03:03.321806Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'ProcessGuid': '365ABB72-AB28-5CB8-0000-0010F2E20000',
#   'ProcessId': 1388,
#   'TargetFilename': 'C:\\Users\\IEUser\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\sysmon.evtx.lnk',
#   'Image': 'C:\\Windows\\Explorer.EXE',
#   'CreationUtcTime': '2019-04-18 17:03:03.311'},
#  {'EventID': 10,
#   'SystemTime': '2019-04-18T17:01:35.720774Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'SourceProcessGuid': [],
#   'SourceProcessId': 1200,
#   'SourceThreadId': 3996,
#   'SourceImage': 'C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe',
#   'TargetProcessGuid': [],
#   'TargetProcessId': 472,
#   'TargetImage': 'C:\\Windows\\system32\\lsass.exe',
#   'GrantedAccess': '0x1010',
#   'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+4595c|C:\\Windows\\system32\\KERNELBASE.dll+8185'},
#  {'EventID': 1,
#   'SystemTime': '2019-04-18T17:00:09.977481Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'IEWIN7',
#   'Hashes': 'SHA1=DC058F52AD8ACBD316827B6DCAC2434AB3CC515C,MD5=0EBF71E33EF09CA65D9683AFA999C473,SHA256=599EFD455AEEEFE2044A9B597061F271595033F5D0DF2C99DFDBCA8394BBCEC3,IMPHASH=C5352B949915AB8CD5E1844790D19274',
#   'Image': 'C:\\Windows\\System32\\whoami.exe',
#   'ParentImage': 'C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe',
#   'CommandLine': '"C:\\Windows\\system32\\whoami.exe"  /user',
#   'ParentCommandLine': 'Powershell',
#   'ProcessId': 3980,
#   'ParentProcessId': 1200},
#  {'EventID': 10,
#   'SystemTime': '2019-04-18T16:58:14.811881Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'SourceProcessGuid': [],
#   'SourceProcessId': 1200,
#   'SourceThreadId': 3096,
#   'SourceImage': 'C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe',
#   'TargetProcessGuid': [],
#   'TargetProcessId': 472,
#   'TargetImage': 'C:\\Windows\\system32\\lsass.exe',
#   'GrantedAccess': '0x1010',
#   'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+4595c|C:\\Windows\\system32\\KERNELBASE.dll+8185'},
#  {'EventID': 3,
#   'SystemTime': '2019-04-18T16:57:52.910388Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'ProcessGuid': '365ABB72-AC60-5CB8-0000-001037BA0800',
#   'ProcessId': 3900,
#   'Image': 'C:\\Windows\\System32\\mmc.exe'},
#  {'EventID': 11,
#   'SystemTime': '2019-04-18T16:57:06.954307Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'ProcessGuid': '365ABB72-AB26-5CB8-0000-0010D1AE0000',
#   'ProcessId': 912,
#   'TargetFilename': 'C:\\Windows\\System32\\Tasks\\Microsoft\\Windows Defender\\MP Scheduled Scan',
#   'Image': 'C:\\Windows\\system32\\svchost.exe',
#   'CreationUtcTime': '2009-07-14 04:42:30.134'},
#  {'EventID': 1,
#   'SystemTime': '2019-04-18T16:57:04.681038Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'IEWIN7',
#   'Hashes': 'SHA1=98D8C5E38510C6220F42747D15F6FFF75DD59845,MD5=A2A5D487D0C3D55739A0491B6872480D,SHA256=40E2B83F07771D54CE4E45B76A14883D042766FF4E1E7872E482EC91E81E9484,IMPHASH=6D2ED4ADDAC7EBAE62381320D82AC4C1',
#   'Image': 'C:\\Windows\\System32\\mmc.exe',
#   'ParentImage': 'C:\\Windows\\System32\\eventvwr.exe',
#   'CommandLine': '"C:\\Windows\\system32\\mmc.exe" "C:\\Windows\\system32\\eventvwr.msc" ',
#   'ParentCommandLine': '"C:\\Windows\\system32\\eventvwr.exe" ',
#   'ProcessId': 3900,
#   'ParentProcessId': 3904},
#  {'EventID': 1,
#   'SystemTime': '2019-04-18T16:56:24.893827Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'IEWIN7',
#   'Hashes': 'SHA1=DC058F52AD8ACBD316827B6DCAC2434AB3CC515C,MD5=0EBF71E33EF09CA65D9683AFA999C473,SHA256=599EFD455AEEEFE2044A9B597061F271595033F5D0DF2C99DFDBCA8394BBCEC3,IMPHASH=C5352B949915AB8CD5E1844790D19274',
#   'Image': 'C:\\Windows\\System32\\whoami.exe',
#   'ParentImage': 'C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe',
#   'CommandLine': '"C:\\Windows\\system32\\whoami.exe"  /user',
#   'ParentCommandLine': 'Powershell',
#   'ProcessId': 3576,
#   'ParentProcessId': 1200},
#  {'EventID': 1,
#   'SystemTime': '2019-04-18T16:56:08.370067Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'IEWIN7',
#   'Hashes': 'SHA1=04C5D2B4DA9A0F3FA8A45702D4256CEE42D8C48D,MD5=92F44E405DB16AC55D97E3BFE3B132FA,SHA256=6C05E11399B7E3C8ED31BAE72014CF249C144A8F4A2C54A758EB2E6FAD47AEC7,IMPHASH=96BA691B035D05F44E35AB23F6BA946C',
#   'Image': 'C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe',
#   'ParentImage': 'C:\\Windows\\System32\\cmd.exe',
#   'CommandLine': 'Powershell',
#   'ParentCommandLine': '"cmd.exe" /s /k pushd "C:\\Users\\IEUser\\Desktop"',
#   'ProcessId': 1200,
#   'ParentProcessId': 1196},
#  {'EventID': 12,
#   'SystemTime': '2019-04-18T16:55:51.285500Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'ProcessGuid': '365ABB72-AC09-5CB8-0000-0010939A0700',
#   'ProcessId': 3192,
#   'Image': 'C:\\Windows\\Sysmon.exe',
#   'TargetObject': 'HKLM\\SOFTWARE\\Microsoft\\EnterpriseCertificates\\Root\\Certificates'},
#  {'EventID': 12,
#   'SystemTime': '2019-04-18T16:55:51.275486Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'ProcessGuid': '365ABB72-AC09-5CB8-0000-0010939A0700',
#   'ProcessId': 3192,
#   'Image': 'C:\\Windows\\Sysmon.exe',
#   'TargetObject': 'HKLM\\SOFTWARE\\Policies\\Microsoft\\SystemCertificates\\Root\\Certificates'},
#  {'EventID': 12,
#   'SystemTime': '2019-04-18T16:55:51.275486Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'ProcessGuid': '365ABB72-AC09-5CB8-0000-0010939A0700',
#   'ProcessId': 3192,
#   'Image': 'C:\\Windows\\Sysmon.exe',
#   'TargetObject': 'HKLM\\SOFTWARE\\Microsoft\\SystemCertificates\\ROOT\\Certificates'},
#  {'EventID': 12,
#   'SystemTime': '2019-04-18T16:55:51.275486Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'ProcessGuid': '365ABB72-AC09-5CB8-0000-0010939A0700',
#   'ProcessId': 3192,
#   'Image': 'C:\\Windows\\Sysmon.exe',
#   'TargetObject': 'HKU\\.DEFAULT\\Software\\Microsoft\\SystemCertificates\\Root\\Certificates'},
#  {'EventID': 5,
#   'SystemTime': '2019-04-18T16:55:44.145233Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'ProcessGuid': '365ABB72-AC10-5CB8-0000-001047A40700',
#   'ProcessId': 3252,
#   'Image': 'C:\\Users\\IEUser\\Desktop\\Sysmon.exe',
#   'ImageLoaded': [],
#   'Description': [],
#   'FileVersion': [],
#   'Product': [],
#   'Hashes': [],
#   'Signed': [],
#   'Signature': [],
#   'SignatureStatus': []},
#  {'EventID': 1,
#   'SystemTime': '2019-04-18T16:55:44.045089Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'IEWIN7',
#   'Hashes': 'SHA1=FF1C037123276983C785F6CDF7EDA5A2FAB06D4A',
#   'Image': 'C:\\Users\\IEUser\\Desktop\\Sysmon.exe',
#   'ParentImage': 'C:\\Windows\\System32\\cmd.exe',
#   'CommandLine': 'sysmon  -c sysmonconfig-18-apr-2019.xml',
#   'ParentCommandLine': '"cmd.exe" /s /k pushd "C:\\Users\\IEUser\\Desktop"',
#   'ProcessId': 3252,
#   'ParentProcessId': 1196},
#  {'EventID': 5,
#   'SystemTime': '2019-04-18T16:55:38.076507Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'ProcessGuid': '365ABB72-AC06-5CB8-0000-001059830700',
#   'ProcessId': 2000,
#   'Image': 'C:\\Users\\IEUser\\Desktop\\Sysmon.exe',
#   'ImageLoaded': [],
#   'Description': [],
#   'FileVersion': [],
#   'Product': [],
#   'Hashes': [],
#   'Signed': [],
#   'Signature': [],
#   'SignatureStatus': []},
#  {'EventID': 1,
#   'SystemTime': '2019-04-18T16:55:37.125139Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'IEWIN7',
#   'Hashes': 'SHA1=393CFBAC0AC28DCC194F88C951D856E74F5B3CB6',
#   'Image': 'C:\\Windows\\System32\\wbem\\unsecapp.exe',
#   'ParentImage': 'C:\\Windows\\System32\\svchost.exe',
#   'CommandLine': 'C:\\Windows\\system32\\wbem\\unsecapp.exe -Embedding',
#   'ParentCommandLine': 'C:\\Windows\\system32\\svchost.exe -k DcomLaunch',
#   'ProcessId': 3232,
#   'ParentProcessId': 588},
#  {'EventID': 1,
#   'SystemTime': '2019-04-18T16:55:37.125139Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'IEWIN7',
#   'Hashes': 'SHA1=FF1C037123276983C785F6CDF7EDA5A2FAB06D4A',
#   'Image': 'C:\\Windows\\Sysmon.exe',
#   'ParentImage': 'C:\\Windows\\System32\\services.exe',
#   'CommandLine': 'C:\\Windows\\Sysmon.exe',
#   'ParentCommandLine': 'C:\\Windows\\system32\\services.exe',
#   'ProcessId': 3192,
#   'ParentProcessId': 464},
#  {'EventID': 4624,
#   'SystemTime': '2020-09-09T13:18:27.714758Z',
#   'SubjectUserSid': 'S-1-5-21-3461203602-4096304019-2269080069-1000',
#   'SubjectUserName': 'IEUser',
#   'SubjectDomainName': 'MSEDGEWIN10',
#   'SubjectLogonId': '0x79e59',
#   'TargetUserSid': 'S-1-5-21-3461203602-4096304019-2269080069-1000',
#   'TargetUserName': 'IEUser',
#   'TargetDomainName': 'MSEDGEWIN10',
#   'TargetLogonId': '0x1cd964',
#   'LogonType': 2,
#   'LogonProcessName': 'Chrome',
#   'WorkstationName': 'MSEDGEWIN10',
#   'TransmittedServices': '-',
#   'ProcessId': '0x1358',
#   'ProcessName': 'C:\\Program Files (x86)\\Google\\Chrome\\Application\\chrome.exe',
#   'IpAddress': '-',
#   'IpPort': '-',
#   'TargetOutboundUserName': '-',
#   'TargetOutboundDomainName': '-'},
#  {'EventID': 4624,
#   'SystemTime': '2020-09-09T13:18:27.714613Z',
#   'SubjectUserSid': 'S-1-5-21-3461203602-4096304019-2269080069-1000',
#   'SubjectUserName': 'IEUser',
#   'SubjectDomainName': 'MSEDGEWIN10',
#   'SubjectLogonId': '0x79e59',
#   'TargetUserSid': 'S-1-5-21-3461203602-4096304019-2269080069-1000',
#   'TargetUserName': 'IEUser',
#   'TargetDomainName': 'MSEDGEWIN10',
#   'TargetLogonId': '0x1cd8f6',
#   'LogonType': 2,
#   'LogonProcessName': 'Chrome',
#   'WorkstationName': 'MSEDGEWIN10',
#   'TransmittedServices': '-',
#   'ProcessId': '0x1358',
#   'ProcessName': 'C:\\Program Files (x86)\\Google\\Chrome\\Application\\chrome.exe',
#   'IpAddress': '-',
#   'IpPort': '-',
#   'TargetOutboundUserName': '-',
#   'TargetOutboundDomainName': '-'},
#  {'EventID': 4624,
#   'SystemTime': '2020-09-09T13:18:25.377120Z',
#   'SubjectUserSid': 'S-1-5-18',
#   'SubjectUserName': 'MSEDGEWIN10$',
#   'SubjectDomainName': 'WORKGROUP',
#   'SubjectLogonId': '0x3e7',
#   'TargetUserSid': 'S-1-5-18',
#   'TargetUserName': 'SYSTEM',
#   'TargetDomainName': 'NT AUTHORITY',
#   'TargetLogonId': '0x3e7',
#   'LogonType': 5,
#   'LogonProcessName': 'Advapi  ',
#   'WorkstationName': '-',
#   'TransmittedServices': '-',
#   'ProcessId': '0x25c',
#   'ProcessName': 'C:\\Windows\\System32\\services.exe',
#   'IpAddress': '-',
#   'IpPort': '-',
#   'TargetOutboundUserName': '-',
#   'TargetOutboundDomainName': '-'},
#  {'EventID': 4625,
#   'SystemTime': '2020-09-09T13:18:23.627952Z',
#   'SubjectUserSid': 'S-1-5-21-3461203602-4096304019-2269080069-1000',
#   'SubjectUserName': 'IEUser',
#   'SubjectDomainName': 'MSEDGEWIN10',
#   'SubjectLogonId': '0x79e59',
#   'TargetUserSid': 'S-1-0-0',
#   'TargetUserName': 'IEUser',
#   'TargetDomainName': 'MSEDGEWIN10',
#   'Status': '0xc000006d',
#   'FailureReason': '%%2313',
#   'SubStatus': '0xc000006a',
#   'LogonType': 2,
#   'LogonProcessName': 'Chrome',
#   'WorkstationName': 'MSEDGEWIN10',
#   'TransmittedServices': '-',
#   'ProcessId': '0x1358',
#   'ProcessName': 'C:\\Program Files (x86)\\Google\\Chrome\\Application\\chrome.exe',
#   'IpPort': '-',
#   'IpAddress': '-'},
#  {'EventID': 4663,
#   'SystemTime': '2019-04-27T19:33:50.134293Z',
#   'SubjectUserSid': 'S-1-5-21-3583694148-1414552638-2922671848-1000',
#   'SubjectUserName': 'IEUser',
#   'SubjectDomainName': 'IEWIN7',
#   'SubjectLogonId': '0xffa8',
#   'ObjectType': 'File',
#   'ObjectName': 'C:\\Users\\IEUser\\AppData\\Local\\Google\\Chrome\\User Data\\Default\\Login Data',
#   'AccessList': '%%4416\r\n\t\t\t\t',
#   'AccessMask': '0x1',
#   'ProcessId': '0x134c',
#   'ProcessName': 'C:\\Users\\Defau1t\\wsus.exe',
#   'ResourceAttributes': []},
#  {'EventID': 4663,
#   'SystemTime': '2019-04-27T19:33:18.699755Z',
#   'SubjectUserSid': 'S-1-5-21-3583694148-1414552638-2922671848-1000',
#   'SubjectUserName': 'IEUser',
#   'SubjectDomainName': 'IEWIN7',
#   'SubjectLogonId': '0xffa8',
#   'ObjectType': 'File',
#   'ObjectName': 'C:\\Users\\IEUser\\AppData\\Roaming\\Mozilla\\Firefox\\Profiles\\kushu3sd.default\\logins.json',
#   'AccessList': '%%4416\r\n\t\t\t\t',
#   'AccessMask': '0x1',
#   'ProcessId': '0x134c',
#   'ProcessName': 'C:\\Users\\Defau1t\\wsus.exe',
#   'ResourceAttributes': []},
#  {'EventID': 4663,
#   'SystemTime': '2019-04-27T19:33:05.308188Z',
#   'SubjectUserSid': 'S-1-5-21-3583694148-1414552638-2922671848-1000',
#   'SubjectUserName': 'IEUser',
#   'SubjectDomainName': 'IEWIN7',
#   'SubjectLogonId': '0xffa8',
#   'ObjectType': 'File',
#   'ObjectName': 'C:\\Users\\IEUser\\AppData\\Roaming\\Mozilla\\Firefox\\Profiles\\kushu3sd.default\\key4.db',
#   'AccessList': '%%4416\r\n\t\t\t\t',
#   'AccessMask': '0x1',
#   'ProcessId': '0x134c',
#   'ProcessName': 'C:\\Users\\Defau1t\\wsus.exe',
#   'ResourceAttributes': []},
#  {'EventID': 4663,
#   'SystemTime': '2019-04-27T19:31:15.355063Z',
#   'SubjectUserSid': 'S-1-5-21-3583694148-1414552638-2922671848-1000',
#   'SubjectUserName': 'IEUser',
#   'SubjectDomainName': 'IEWIN7',
#   'SubjectLogonId': '0xffa8',
#   'ObjectType': 'File',
#   'ObjectName': 'C:\\Users\\IEUser\\AppData\\Roaming\\Opera Software\\Opera Stable\\Login Data',
#   'AccessList': '%%4416\r\n\t\t\t\t',
#   'AccessMask': '0x1',
#   'ProcessId': '0x134c',
#   'ProcessName': 'C:\\Users\\Defau1t\\wsus.exe',
#   'ResourceAttributes': []},
#  {'EventID': 4663,
#   'SystemTime': '2020-03-08T22:11:34.340584Z',
#   'SubjectUserSid': 'S-1-5-21-3461203602-4096304019-2269080069-1000',
#   'SubjectUserName': 'IEUser',
#   'SubjectDomainName': 'MSEDGEWIN10',
#   'SubjectLogonId': '0x33392',
#   'ObjectType': 'Process',
#   'ObjectName': '\\Device\\HarddiskVolume1\\Windows\\System32\\lsass.exe',
#   'AccessList': '%%4484\r\n\t\t\t\t',
#   'AccessMask': '0x10',
#   'ProcessId': '0x1688',
#   'ProcessName': 'C:\\Windows\\System32\\cscript.exe',
#   'ResourceAttributes': '-'},
#  {'EventID': 5,
#   'SystemTime': '2019-04-27T18:47:00.124974Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'ProcessGuid': '365ABB72-A3A4-5CC4-0000-001084960C00',
#   'ProcessId': 1288,
#   'Image': 'C:\\Users\\Public\\KeeFarce.exe',
#   'ImageLoaded': [],
#   'Description': [],
#   'FileVersion': [],
#   'Product': [],
#   'Hashes': [],
#   'Signed': [],
#   'Signature': [],
#   'SignatureStatus': []},
#  {'EventID': 8,
#   'SystemTime': '2019-04-27T18:47:00.062474Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'SourceProcessGuid': '365ABB72-A3A4-5CC4-0000-001084960C00',
#   'SourceProcessId': 1288,
#   'TargetProcessGuid': '365ABB72-A201-5CC4-0000-00104F500800',
#   'TargetProcessId': 2364,
#   'SourceImage': 'C:\\Users\\Public\\KeeFarce.exe',
#   'TargetImage': 'C:\\Program Files\\KeePass Password Safe 2\\KeePass.exe',
#   'NewThreadId': 1920,
#   'StartAddress': '0x5A801260',
#   'StartModule': 'C:\\Users\\Public\\BootstrapDLL.dll',
#   'StartFunction': 'LoadManagedProject'},
#  {'EventID': 1,
#   'SystemTime': '2019-04-27T18:47:00.046849Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'IEWIN7',
#   'Hashes': 'SHA1=C622268A9305BA27C78ECB5FFCC1D43B019847B5,MD5=07D86CD24E11C1B8F0C2F2029F9D3466,SHA256=F0D5C8E6DF82A7B026F4F0412F8EDE11A053185675D965215B1FFBBC52326516,IMPHASH=D94F14D149DD5809F1B4D1C38A1B4E40',
#   'Image': 'C:\\Users\\Public\\KeeFarce.exe',
#   'ParentImage': 'C:\\Windows\\System32\\cmd.exe',
#   'CommandLine': 'KeeFarce.exe',
#   'ParentCommandLine': '"C:\\Windows\\System32\\cmd.exe" ',
#   'ProcessId': 1288,
#   'ParentProcessId': 3680},
#  {'EventID': 8,
#   'SystemTime': '2019-04-27T18:55:04.980137Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'SourceProcessGuid': '365ABB72-A512-5CC4-0000-0010C05E1B00',
#   'SourceProcessId': 2856,
#   'TargetProcessGuid': '365ABB72-A201-5CC4-0000-00104F500800',
#   'TargetProcessId': 2364,
#   'SourceImage': 'C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe',
#   'TargetImage': 'C:\\Program Files\\KeePass Password Safe 2\\KeePass.exe',
#   'NewThreadId': 1384,
#   'StartAddress': '0x06160000',
#   'StartModule': '',
#   'StartFunction': ''},
#  {'EventID': 8,
#   'SystemTime': '2019-04-27T18:55:04.710608Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'SourceProcessGuid': '365ABB72-A512-5CC4-0000-0010C05E1B00',
#   'SourceProcessId': 2856,
#   'TargetProcessGuid': '365ABB72-A201-5CC4-0000-00104F500800',
#   'TargetProcessId': 2364,
#   'SourceImage': 'C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe',
#   'TargetImage': 'C:\\Program Files\\KeePass Password Safe 2\\KeePass.exe',
#   'NewThreadId': 3796,
#   'StartAddress': '0x76FAEC4B',
#   'StartModule': 'C:\\Windows\\SYSTEM32\\ntdll.dll',
#   'StartFunction': 'DbgUiRemoteBreakin'},
#  {'EventID': 11,
#   'SystemTime': '2020-09-11T12:10:22.398726Z',
#   'Computer': 'MSEDGEWIN10',
#   'UserID': 'S-1-5-18',
#   'ProcessGuid': '747F3D96-672C-5F5B-0D00-00000000FC00',
#   'ProcessId': 640,
#   'TargetFilename': 'C:\\Windows\\System32\\mimilsa.log',
#   'Image': 'C:\\Windows\\system32\\lsass.exe',
#   'CreationUtcTime': '2020-09-11 12:10:22.357'},
#  {'EventID': 8,
#   'SystemTime': '2019-04-30T12:43:43.784179Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'SourceProcessGuid': '365ABB72-4055-5CC8-0000-0010769D0B00',
#   'SourceProcessId': 1532,
#   'TargetProcessGuid': '365ABB72-3FE0-5CC8-0000-00107E590000',
#   'TargetProcessId': 492,
#   'SourceImage': '\\\\VBOXSVR\\HTools\\voice_mail.msg.exe',
#   'TargetImage': 'C:\\Windows\\System32\\lsass.exe',
#   'NewThreadId': 3656,
#   'StartAddress': '0x001A0000',
#   'StartModule': '',
#   'StartFunction': ''},
#  {'EventID': 10,
#   'SystemTime': '2019-04-30T12:43:43.784179Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'SourceProcessGuid': [],
#   'SourceProcessId': 1532,
#   'SourceThreadId': 2284,
#   'SourceImage': '\\\\VBOXSVR\\HTools\\voice_mail.msg.exe',
#   'TargetProcessGuid': [],
#   'TargetProcessId': 492,
#   'TargetImage': 'C:\\Windows\\system32\\lsass.exe',
#   'GrantedAccess': '0x1f1fff',
#   'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+4595c|C:\\Windows\\system32\\KERNELBASE.dll+8185|UNKNOWN(01B51606)|UNKNOWN(01B51F41)|UNKNOWN(01B51515)|UNKNOWN(014A7486)|UNKNOWN(014A73A0)|UNKNOWN(014A78A3)|C:\\Windows\\system32\\kernel32.dll+4ef8c|C:\\Windows\\SYSTEM32\\ntdll.dll+6367a|C:\\Windows\\SYSTEM32\\ntdll.dll+6364d'},
#  {'EventID': 10,
#   'SystemTime': '2019-04-30T12:43:43.784179Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'SourceProcessGuid': [],
#   'SourceProcessId': 1532,
#   'SourceThreadId': 2284,
#   'SourceImage': '\\\\VBOXSVR\\HTools\\voice_mail.msg.exe',
#   'TargetProcessGuid': [],
#   'TargetProcessId': 468,
#   'TargetImage': 'C:\\Windows\\system32\\services.exe',
#   'GrantedAccess': '0x1f1fff',
#   'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+4595c|C:\\Windows\\system32\\KERNELBASE.dll+8185|UNKNOWN(01B51606)|UNKNOWN(01B51F41)|UNKNOWN(01B51515)|UNKNOWN(014A7486)|UNKNOWN(014A73A0)|UNKNOWN(014A78A3)|C:\\Windows\\system32\\kernel32.dll+4ef8c|C:\\Windows\\SYSTEM32\\ntdll.dll+6367a|C:\\Windows\\SYSTEM32\\ntdll.dll+6364d'},
#  {'EventID': 10,
#   'SystemTime': '2019-04-30T12:43:43.784179Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'SourceProcessGuid': [],
#   'SourceProcessId': 1532,
#   'SourceThreadId': 2284,
#   'SourceImage': '\\\\VBOXSVR\\HTools\\voice_mail.msg.exe',
#   'TargetProcessGuid': [],
#   'TargetProcessId': 440,
#   'TargetImage': 'C:\\Windows\\system32\\winlogon.exe',
#   'GrantedAccess': '0x1f1fff',
#   'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+4595c|C:\\Windows\\system32\\KERNELBASE.dll+8185|UNKNOWN(01B51606)|UNKNOWN(01B51F41)|UNKNOWN(01B51515)|UNKNOWN(014A7486)|UNKNOWN(014A73A0)|UNKNOWN(014A78A3)|C:\\Windows\\system32\\kernel32.dll+4ef8c|C:\\Windows\\SYSTEM32\\ntdll.dll+6367a|C:\\Windows\\SYSTEM32\\ntdll.dll+6364d'},
#  {'EventID': 10,
#   'SystemTime': '2019-04-30T12:43:43.784179Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'SourceProcessGuid': [],
#   'SourceProcessId': 1532,
#   'SourceThreadId': 2284,
#   'SourceImage': '\\\\VBOXSVR\\HTools\\voice_mail.msg.exe',
#   'TargetProcessGuid': [],
#   'TargetProcessId': 392,
#   'TargetImage': 'C:\\Windows\\system32\\wininit.exe',
#   'GrantedAccess': '0x1f1fff',
#   'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+4595c|C:\\Windows\\system32\\KERNELBASE.dll+8185|UNKNOWN(01B51606)|UNKNOWN(01B51F41)|UNKNOWN(01B51515)|UNKNOWN(014A7486)|UNKNOWN(014A73A0)|UNKNOWN(014A78A3)|C:\\Windows\\system32\\kernel32.dll+4ef8c|C:\\Windows\\SYSTEM32\\ntdll.dll+6367a|C:\\Windows\\SYSTEM32\\ntdll.dll+6364d'},
#  {'EventID': 10,
#   'SystemTime': '2019-04-30T12:43:43.784179Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'SourceProcessGuid': [],
#   'SourceProcessId': 1532,
#   'SourceThreadId': 2284,
#   'SourceImage': '\\\\VBOXSVR\\HTools\\voice_mail.msg.exe',
#   'TargetProcessGuid': [],
#   'TargetProcessId': 384,
#   'TargetImage': 'C:\\Windows\\system32\\csrss.exe',
#   'GrantedAccess': '0x1f1fff',
#   'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+4595c|C:\\Windows\\system32\\KERNELBASE.dll+8185|UNKNOWN(01B51606)|UNKNOWN(01B51F41)|UNKNOWN(01B51515)|UNKNOWN(014A7486)|UNKNOWN(014A73A0)|UNKNOWN(014A78A3)|C:\\Windows\\system32\\kernel32.dll+4ef8c|C:\\Windows\\SYSTEM32\\ntdll.dll+6367a|C:\\Windows\\SYSTEM32\\ntdll.dll+6364d'},
#  {'EventID': 8,
#   'SystemTime': '2019-04-30T12:43:43.784179Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'SourceProcessGuid': '365ABB72-4055-5CC8-0000-0010769D0B00',
#   'SourceProcessId': 1532,
#   'TargetProcessGuid': '365ABB72-3FE0-5CC8-0000-00107E590000',
#   'TargetProcessId': 492,
#   'SourceImage': '\\\\VBOXSVR\\HTools\\voice_mail.msg.exe',
#   'TargetImage': 'C:\\Windows\\System32\\lsass.exe',
#   'NewThreadId': 1744,
#   'StartAddress': '0x001A0000',
#   'StartModule': '',
#   'StartFunction': ''},
#  {'EventID': 10,
#   'SystemTime': '2019-04-30T12:43:43.784179Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'SourceProcessGuid': [],
#   'SourceProcessId': 1532,
#   'SourceThreadId': 2284,
#   'SourceImage': '\\\\VBOXSVR\\HTools\\voice_mail.msg.exe',
#   'TargetProcessGuid': [],
#   'TargetProcessId': 336,
#   'TargetImage': 'C:\\Windows\\system32\\csrss.exe',
#   'GrantedAccess': '0x1f1fff',
#   'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+4595c|C:\\Windows\\system32\\KERNELBASE.dll+8185|UNKNOWN(01B51606)|UNKNOWN(01B51F41)|UNKNOWN(01B51515)|UNKNOWN(014A7486)|UNKNOWN(014A73A0)|UNKNOWN(014A78A3)|C:\\Windows\\system32\\kernel32.dll+4ef8c|C:\\Windows\\SYSTEM32\\ntdll.dll+6367a|C:\\Windows\\SYSTEM32\\ntdll.dll+6364d'},
#  {'EventID': 10,
#   'SystemTime': '2019-04-30T12:43:43.784179Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'SourceProcessGuid': [],
#   'SourceProcessId': 1532,
#   'SourceThreadId': 2284,
#   'SourceImage': '\\\\VBOXSVR\\HTools\\voice_mail.msg.exe',
#   'TargetProcessGuid': [],
#   'TargetProcessId': 264,
#   'TargetImage': 'C:\\Windows\\System32\\smss.exe',
#   'GrantedAccess': '0x1f1fff',
#   'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+4595c|C:\\Windows\\system32\\KERNELBASE.dll+8185|UNKNOWN(01B51606)|UNKNOWN(01B51F41)|UNKNOWN(01B51515)|UNKNOWN(014A7486)|UNKNOWN(014A73A0)|UNKNOWN(014A78A3)|C:\\Windows\\system32\\kernel32.dll+4ef8c|C:\\Windows\\SYSTEM32\\ntdll.dll+6367a|C:\\Windows\\SYSTEM32\\ntdll.dll+6364d'},
#  {'EventID': 10,
#   'SystemTime': '2020-07-24T17:20:29.872554Z',
#   'Computer': 'LAPTOP-JU4M3I0E',
#   'UserID': 'S-1-5-18',
#   'SourceProcessGuid': [],
#   'SourceProcessId': 18192,
#   'SourceThreadId': 7412,
#   'SourceImage': 'C:\\Users\\bouss\\AppData\\Local\\Temp\\frida-b4f3ceb41e16327436594aec059ee5d5\\frida-winjector-helper-32.exe',
#   'TargetProcessGuid': [],
#   'TargetProcessId': 2960,
#   'TargetImage': 'C:\\Program Files (x86)\\TeamViewer\\TeamViewer.exe',
#   'GrantedAccess': '0x147a',
#   'CallTrace': 'C:\\windows\\SYSTEM32\\ntdll.dll+9c534|C:\\windows\\System32\\wow64.dll+ba94|C:\\windows\\System32\\wow64.dll+7123|C:\\windows\\System32\\wow64cpu.dll+1783|C:\\windows\\System32\\wow64cpu.dll+1199|C:\\windows\\System32\\wow64.dll+c77a|C:\\windows\\System32\\wow64.dll+c637|C:\\windows\\SYSTEM32\\ntdll.dll+d3f73|C:\\windows\\SYSTEM32\\ntdll.dll+c1d75|C:\\windows\\SYSTEM32\\ntdll.dll+717d3|C:\\windows\\SYSTEM32\\ntdll.dll+7177e|C:\\windows\\SYSTEM32\\ntdll.dll+7208c(wow64)|C:\\windows\\System32\\KERNELBASE.dll+f1088(wow64)|C:\\Users\\bouss\\AppData\\Local\\Temp\\frida-b4f3ceb41e16327436594aec059ee5d5\\frida-winjector-helper-32.exe+acf1|C:\\Users\\bouss\\AppData\\Local\\Temp\\frida-b4f3ceb41e16327436594aec059ee5d5\\frida-winjector-helper-32.exe+33b3|C:\\Users\\bouss\\AppData\\Local\\Temp\\frida-b4f3ceb41e16327436594aec059ee5d5\\frida-winjector-helper-32.exe+32c4|C:\\Users\\bouss\\AppData\\Local\\Temp\\frida-b4f3ceb41e16327436594aec059ee5d5\\frida-winjector-helper-32.exe+3f0c|C:\\Users\\bouss\\AppData\\Local\\Temp\\frida-b4f3ceb41e16327436594aec059ee5d5\\frida-winjector-helper-32.exe+3c29|C:\\Users\\bouss\\AppData\\Local\\Temp\\frida-b4f3ceb41e16327436594aec059ee5d5\\frida-winjector-helper-32.exe+3b31|C:\\Users\\bouss\\AppData\\Local\\Temp\\frida-b4f3ceb41e16327436594aec059ee5d5\\frida-winjector-helper-32.exe+be65'},
#  {'EventID': 1,
#   'SystemTime': '2019-05-27T01:29:17.731362Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'IEWIN7',
#   'Hashes': 'SHA1=C5423FEF0E8E211BB8BAB9C11E730048BBED7B29,MD5=0E5BC786206A3762CE47A0A2DBD01D7B,SHA256=113F68086A3F02276395CB70C72B00ED33A47FD00820D229093CD6ADDC2F73F4,IMPHASH=1697BBEAB0AC62DD7B8016CE25425F45',
#   'Image': 'C:\\Windows\\System32\\inetsrv\\appcmd.exe',
#   'ParentImage': 'C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe',
#   'CommandLine': '"C:\\Windows\\System32\\inetsrv\\appcmd.exe"  list apppool "Filename: redirection.config" /text:processmodel.password',
#   'ParentCommandLine': '"C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe"  -nop -noni -enc ...',
#   'ProcessId': 2448,
#   'ParentProcessId': 2584},
#  {'EventID': 1,
#   'SystemTime': '2019-05-27T01:29:17.661261Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'IEWIN7',
#   'Hashes': 'SHA1=C5423FEF0E8E211BB8BAB9C11E730048BBED7B29,MD5=0E5BC786206A3762CE47A0A2DBD01D7B,SHA256=113F68086A3F02276395CB70C72B00ED33A47FD00820D229093CD6ADDC2F73F4,IMPHASH=1697BBEAB0AC62DD7B8016CE25425F45',
#   'Image': 'C:\\Windows\\System32\\inetsrv\\appcmd.exe',
#   'ParentImage': 'C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe',
#   'CommandLine': '"C:\\Windows\\System32\\inetsrv\\appcmd.exe"  list apppool "Filename: redirection.config" /text:processmodel.username',
#   'ParentCommandLine': '"C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe"  -nop -noni -enc ...',
#   'ProcessId': 1340,
#   'ParentProcessId': 2584},
#  {'EventID': 1,
#   'SystemTime': '2019-05-27T01:29:17.581146Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'IEWIN7',
#   'Hashes': 'SHA1=C5423FEF0E8E211BB8BAB9C11E730048BBED7B29,MD5=0E5BC786206A3762CE47A0A2DBD01D7B,SHA256=113F68086A3F02276395CB70C72B00ED33A47FD00820D229093CD6ADDC2F73F4,IMPHASH=1697BBEAB0AC62DD7B8016CE25425F45',
#   'Image': 'C:\\Windows\\System32\\inetsrv\\appcmd.exe',
#   'ParentImage': 'C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe',
#   'CommandLine': '"C:\\Windows\\System32\\inetsrv\\appcmd.exe"  list apppool /text:processmodel.password',
#   'ParentCommandLine': '"C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe"  -nop -noni -enc ...',
#   'ProcessId': 2928,
#   'ParentProcessId': 2584},
#  {'EventID': 1,
#   'SystemTime': '2019-05-27T01:29:17.350815Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'IEWIN7',
#   'Hashes': 'SHA1=C5423FEF0E8E211BB8BAB9C11E730048BBED7B29,MD5=0E5BC786206A3762CE47A0A2DBD01D7B,SHA256=113F68086A3F02276395CB70C72B00ED33A47FD00820D229093CD6ADDC2F73F4,IMPHASH=1697BBEAB0AC62DD7B8016CE25425F45',
#   'Image': 'C:\\Windows\\System32\\inetsrv\\appcmd.exe',
#   'ParentImage': 'C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe',
#   'CommandLine': '"C:\\Windows\\System32\\inetsrv\\appcmd.exe"  list apppool /text:processmodel.username',
#   'ParentCommandLine': '"C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe"  -nop -noni -enc ...',
#   'ProcessId': 3096,
#   'ParentProcessId': 2584},
#  {'EventID': 1,
#   'SystemTime': '2019-05-27T01:29:17.270700Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'IEWIN7',
#   'Hashes': 'SHA1=C5423FEF0E8E211BB8BAB9C11E730048BBED7B29,MD5=0E5BC786206A3762CE47A0A2DBD01D7B,SHA256=113F68086A3F02276395CB70C72B00ED33A47FD00820D229093CD6ADDC2F73F4,IMPHASH=1697BBEAB0AC62DD7B8016CE25425F45',
#   'Image': 'C:\\Windows\\System32\\inetsrv\\appcmd.exe',
#   'ParentImage': 'C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe',
#   'CommandLine': '"C:\\Windows\\System32\\inetsrv\\appcmd.exe"  list apppool "ERROR ( message:Configuration error " /text:processmodel.password',
#   'ParentCommandLine': '"C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe"  -nop -noni -enc ...',
#   'ProcessId': 3240,
#   'ParentProcessId': 2584},
#  {'EventID': 1,
#   'SystemTime': '2019-05-27T01:29:17.190585Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'IEWIN7',
#   'Hashes': 'SHA1=C5423FEF0E8E211BB8BAB9C11E730048BBED7B29,MD5=0E5BC786206A3762CE47A0A2DBD01D7B,SHA256=113F68086A3F02276395CB70C72B00ED33A47FD00820D229093CD6ADDC2F73F4,IMPHASH=1697BBEAB0AC62DD7B8016CE25425F45',
#   'Image': 'C:\\Windows\\System32\\inetsrv\\appcmd.exe',
#   'ParentImage': 'C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe',
#   'CommandLine': '"C:\\Windows\\System32\\inetsrv\\appcmd.exe"  list apppool "ERROR ( message:Configuration error " /text:processmodel.username',
#   'ParentCommandLine': '"C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe"  -nop -noni -enc ...',
#   'ProcessId': 2104,
#   'ParentProcessId': 2584},
#  {'EventID': 1,
#   'SystemTime': '2019-05-27T01:29:17.110469Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'IEWIN7',
#   'Hashes': 'SHA1=C5423FEF0E8E211BB8BAB9C11E730048BBED7B29,MD5=0E5BC786206A3762CE47A0A2DBD01D7B,SHA256=113F68086A3F02276395CB70C72B00ED33A47FD00820D229093CD6ADDC2F73F4,IMPHASH=1697BBEAB0AC62DD7B8016CE25425F45',
#   'Image': 'C:\\Windows\\System32\\inetsrv\\appcmd.exe',
#   'ParentImage': 'C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe',
#   'CommandLine': '"C:\\Windows\\System32\\inetsrv\\appcmd.exe"  list apppools /text:name',
#   'ParentCommandLine': '"C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe"  -nop -noni -enc ...',
#   'ProcessId': 2644,
#   'ParentProcessId': 2584},
#  {'EventID': 1,
#   'SystemTime': '2019-05-27T01:29:17.000311Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'IEWIN7',
#   'Hashes': 'SHA1=C5423FEF0E8E211BB8BAB9C11E730048BBED7B29,MD5=0E5BC786206A3762CE47A0A2DBD01D7B,SHA256=113F68086A3F02276395CB70C72B00ED33A47FD00820D229093CD6ADDC2F73F4,IMPHASH=1697BBEAB0AC62DD7B8016CE25425F45',
#   'Image': 'C:\\Windows\\System32\\inetsrv\\appcmd.exe',
#   'ParentImage': 'C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe',
#   'CommandLine': '"C:\\Windows\\System32\\InetSRV\\appcmd.exe"  list vdir /text:physicalpath',
#   'ParentCommandLine': '"C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe"  -nop -noni -enc ...',
#   'ProcessId': 3484,
#   'ParentProcessId': 2584},
#  {'EventID': 1,
#   'SystemTime': '2019-05-27T01:28:42.711005Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'IEWIN7',
#   'Hashes': 'SHA1=04C5D2B4DA9A0F3FA8A45702D4256CEE42D8C48D,MD5=92F44E405DB16AC55D97E3BFE3B132FA,SHA256=6C05E11399B7E3C8ED31BAE72014CF249C144A8F4A2C54A758EB2E6FAD47AEC7,IMPHASH=96BA691B035D05F44E35AB23F6BA946C',
#   'Image': 'C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe',
#   'ParentImage': 'C:\\Windows\\System32\\inetsrv\\w3wp.exe',
#   'CommandLine': '"C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe"  -nop -noni -enc ...',
#   'ParentCommandLine': 'c:\\windows\\system32\\inetsrv\\w3wp.exe -ap "DefaultAppPool" -v "v2.0" -l "webengine4.dll" -a \\\\.\\pipe\\iisipm7486e07c-453c-4f8e-85c6-8c8e3be98cd5 -h "C:\\inetpub\\temp\\apppools\\DefaultAppPool\\DefaultAppPool.config" -w "" -m 0 -t 20',
#   'ProcessId': 2584,
#   'ParentProcessId': 748},
#  {'EventID': 1,
#   'SystemTime': '2019-05-27T01:29:18.432370Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'IEWIN7',
#   'Hashes': 'SHA1=C5423FEF0E8E211BB8BAB9C11E730048BBED7B29,MD5=0E5BC786206A3762CE47A0A2DBD01D7B,SHA256=113F68086A3F02276395CB70C72B00ED33A47FD00820D229093CD6ADDC2F73F4,IMPHASH=1697BBEAB0AC62DD7B8016CE25425F45',
#   'Image': 'C:\\Windows\\System32\\inetsrv\\appcmd.exe',
#   'ParentImage': 'C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe',
#   'CommandLine': '"C:\\Windows\\System32\\inetsrv\\appcmd.exe"  list apppool /text:processmodel.username',
#   'ParentCommandLine': '"C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe"  -nop -noni -enc ...',
#   'ProcessId': 3136,
#   'ParentProcessId': 2584},
#  {'EventID': 1,
#   'SystemTime': '2019-05-27T01:29:18.352255Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'IEWIN7',
#   'Hashes': 'SHA1=C5423FEF0E8E211BB8BAB9C11E730048BBED7B29,MD5=0E5BC786206A3762CE47A0A2DBD01D7B,SHA256=113F68086A3F02276395CB70C72B00ED33A47FD00820D229093CD6ADDC2F73F4,IMPHASH=1697BBEAB0AC62DD7B8016CE25425F45',
#   'Image': 'C:\\Windows\\System32\\inetsrv\\appcmd.exe',
#   'ParentImage': 'C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe',
#   'CommandLine': '"C:\\Windows\\System32\\inetsrv\\appcmd.exe"  list apppool "Description: Cannot read configuration file due to insufficient permissions" /text:processmodel.password',
#   'ParentCommandLine': '"C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe"  -nop -noni -enc ...',
#   'ProcessId': 3100,
#   'ParentProcessId': 2584},
#  {'EventID': 1,
#   'SystemTime': '2019-05-27T01:29:18.282154Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'IEWIN7',
#   'Hashes': 'SHA1=C5423FEF0E8E211BB8BAB9C11E730048BBED7B29,MD5=0E5BC786206A3762CE47A0A2DBD01D7B,SHA256=113F68086A3F02276395CB70C72B00ED33A47FD00820D229093CD6ADDC2F73F4,IMPHASH=1697BBEAB0AC62DD7B8016CE25425F45',
#   'Image': 'C:\\Windows\\System32\\inetsrv\\appcmd.exe',
# ...
#   'Computer': 'MSEDGEWIN10',
#   'UserID': 'S-1-5-18',
#   'SourceProcessGuid': [],
#   'SourceProcessId': 2888,
#   'SourceThreadId': 2796,
#   'SourceImage': 'C:\\Windows\\system32\\rundll32.exe',
#   'TargetProcessGuid': [],
#   'TargetProcessId': 4868,
#   'TargetImage': 'C:\\Windows\\system32\\notepad.exe',
#   'GrantedAccess': '0x1fffff',
#   'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+9fc24|C:\\Windows\\SYSTEM32\\ntdll.dll+7a747|C:\\Windows\\System32\\KERNEL32.DLL+1c5b4|C:\\Windows\\System32\\KERNEL32.DLL+237f8|C:\\Windows\\SYSTEM32\\dbgcore.DLL+9247|C:\\Windows\\SYSTEM32\\dbgcore.DLL+15dc5|C:\\Windows\\SYSTEM32\\dbgcore.DLL+fec6|C:\\Windows\\SYSTEM32\\dbgcore.DLL+5f56|C:\\Windows\\SYSTEM32\\dbgcore.DLL+69f7|C:\\windows\\system32\\comsvcs.dll+3c3d4|C:\\Windows\\system32\\rundll32.exe+3bcf|C:\\Windows\\system32\\rundll32.exe+6299|C:\\Windows\\System32\\KERNEL32.DLL+17974|C:\\Windows\\SYSTEM32\\ntdll.dll+6a271'},
#  {'EventID': 11,
#   'SystemTime': '2019-08-30T12:54:08.396724Z',
#   'Computer': 'MSEDGEWIN10',
#   'UserID': 'S-1-5-18',
#   'ProcessGuid': '747F3D96-1C70-5D69-0000-0010C9661F00',
#   'ProcessId': 2888,
#   'TargetFilename': 'C:\\Windows\\System32\\notepad.bin',
#   'Image': 'C:\\Windows\\system32\\rundll32.exe',
#   'CreationUtcTime': '2019-08-30 12:54:08.392'},
#  {'EventID': 1,
#   'SystemTime': '2019-08-30T12:54:08.354049Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'MSEDGEWIN10',
#   'Hashes': 'SHA1=F3BA3415DD068A8871F285570BEA2E29874CBFF1,MD5=C73BA51880F5A7FB20C84185A23212EF,SHA256=01B407AF0200B66A34D9B1FA6D9EAAB758EFA36A36BB99B554384F59F8690B1A,IMPHASH=F27A7FC3A53E74F45BE370131953896A',
#   'Image': 'C:\\Windows\\System32\\rundll32.exe',
#   'ParentImage': 'C:\\Windows\\System32\\wbem\\WmiPrvSE.exe',
#   'CommandLine': 'rundll32 C:\\windows\\system32\\comsvcs.dll, MiniDump 4868 C:\\Windows\\System32\\notepad.bin full',
#   'ParentCommandLine': 'C:\\Windows\\system32\\wbem\\wmiprvse.exe -secured -Embedding',
#   'ProcessId': 2888,
#   'ParentProcessId': 1144},
#  {'EventID': 1,
#   'SystemTime': '2019-08-30T12:54:07.873789Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'MSEDGEWIN10',
#   'Hashes': 'SHA1=0E3C0779D8EAAD3B00363D7890DDC8272B510D49,MD5=A45586B3A5A291516CD10EF4FD3EE768,SHA256=59D3CDC7D51FA34C6B27B8B04EA17992955466EB25022B7BD64880AB35DF0BBC,IMPHASH=2B44D2206B9865383429E9C1524F1CAC',
#   'Image': 'C:\\Windows\\System32\\cscript.exe',
#   'ParentImage': 'C:\\Windows\\System32\\cmd.exe',
#   'CommandLine': 'cscript  c:\\ProgramData\\memdump.vbs notepad.exe',
#   'ParentCommandLine': 'C:\\Windows\\System32\\cmd.exe',
#   'ProcessId': 2576,
#   'ParentProcessId': 2128},
#  {'EventID': 10,
#   'SystemTime': '2019-03-17T19:37:11.661930Z',
#   'Computer': 'PC04.example.corp',
#   'UserID': 'S-1-5-18',
#   'SourceProcessGuid': [],
#   'SourceProcessId': 3588,
#   'SourceThreadId': 2272,
#   'SourceImage': 'C:\\Users\\IEUser\\Desktop\\mimikatz_trunk\\Win32\\mimikatz.exe',
#   'TargetProcessGuid': [],
#   'TargetProcessId': 476,
#   'TargetImage': 'C:\\Windows\\system32\\lsass.exe',
#   'GrantedAccess': '0x1010',
#   'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+4595c|C:\\Windows\\system32\\KERNELBASE.dll+8185|C:\\Users\\IEUser\\Desktop\\mimikatz_trunk\\Win32\\mimikatz.exe+5c5a9|C:\\Users\\IEUser\\Desktop\\mimikatz_trunk\\Win32\\mimikatz.exe+5c86c|C:\\Users\\IEUser\\Desktop\\mimikatz_trunk\\Win32\\mimikatz.exe+5cbd2|C:\\Users\\IEUser\\Desktop\\mimikatz_trunk\\Win32\\mimikatz.exe+5c4ff|C:\\Users\\IEUser\\Desktop\\mimikatz_trunk\\Win32\\mimikatz.exe+3b3d3'},
#  {'EventID': 1,
#   'SystemTime': '2019-03-17T20:43:16.309727Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'PC04.example.corp',
#   'Hashes': 'MD5=D861EB4D6719D6738270E6A376B87F18,IMPHASH=B54B63A98C9E12C1902D75D180ABBF38',
#   'Image': 'C:\\Windows\\System32\\slui.exe',
#   'ParentImage': 'C:\\Windows\\System32\\svchost.exe',
#   'CommandLine': 'C:\\Windows\\System32\\slui.exe -Embedding',
#   'ParentCommandLine': 'C:\\Windows\\system32\\svchost.exe -k DcomLaunch',
#   'ProcessId': 3312,
#   'ParentProcessId': 608},
#  {'EventID': 1,
#   'SystemTime': '2019-03-17T20:43:12.784659Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'PC04.example.corp',
#   'Hashes': 'MD5=8344FD4FCE927880AA1AA7681D4927E5,IMPHASH=5DE0CABE853D959C3319B51C8EC562E6',
#   'Image': 'C:\\Windows\\System32\\UI0Detect.exe',
#   'ParentImage': 'C:\\Windows\\System32\\UI0Detect.exe',
#   'CommandLine': 'UI0Detect.exe 220',
#   'ParentCommandLine': 'C:\\Windows\\system32\\UI0Detect.exe',
#   'ProcessId': 136,
#   'ParentProcessId': 1768},
#  {'EventID': 13,
#   'SystemTime': '2019-03-17T20:42:51.504059Z',
#   'Computer': 'PC04.example.corp',
#   'UserID': 'S-1-5-18',
#   'ProcessGuid': '365ABB72-B138-5C8E-0000-001004F51200',
#   'ProcessId': 848,
#   'Image': 'C:\\Users\\IEUser\\Desktop\\keylogger_directx.exe',
#   'TargetObject': 'HKU\\S-1-5-21-3583694148-1414552638-2922671848-1000\\Software\\Microsoft\\DirectInput\\MostRecentApplication\\MostRecentStart',
#   'Details': 'Binary Data'},
#  {'EventID': 13,
#   'SystemTime': '2019-03-17T20:42:51.504059Z',
#   'Computer': 'PC04.example.corp',
#   'UserID': 'S-1-5-18',
#   'ProcessGuid': '365ABB72-B138-5C8E-0000-001004F51200',
#   'ProcessId': 848,
#   'Image': 'C:\\Users\\IEUser\\Desktop\\keylogger_directx.exe',
#   'TargetObject': 'HKU\\S-1-5-21-3583694148-1414552638-2922671848-1000\\Software\\Microsoft\\DirectInput\\MostRecentApplication\\Id',
#   'Details': 'KEYLOGGER_DIRECTX.EXE4755D1CB0002A410'},
#  {'EventID': 13,
#   'SystemTime': '2019-03-17T20:42:51.504059Z',
#   'Computer': 'PC04.example.corp',
#   'UserID': 'S-1-5-18',
#   'ProcessGuid': '365ABB72-B138-5C8E-0000-001004F51200',
#   'ProcessId': 848,
#   'Image': 'C:\\Users\\IEUser\\Desktop\\keylogger_directx.exe',
#   'TargetObject': 'HKU\\S-1-5-21-3583694148-1414552638-2922671848-1000\\Software\\Microsoft\\DirectInput\\MostRecentApplication\\Name',
#   'Details': 'KEYLOGGER_DIRECTX.EXE'},
#  {'EventID': 13,
#   'SystemTime': '2019-03-17T20:42:51.504059Z',
#   'Computer': 'PC04.example.corp',
#   'UserID': 'S-1-5-18',
#   'ProcessGuid': '365ABB72-B138-5C8E-0000-001004F51200',
#   'ProcessId': 848,
#   'Image': 'C:\\Users\\IEUser\\Desktop\\keylogger_directx.exe',
#   'TargetObject': 'HKU\\S-1-5-21-3583694148-1414552638-2922671848-1000\\Software\\Microsoft\\DirectInput\\MostRecentApplication\\Version',
#   'Details': 'Binary Data'},
#  {'EventID': 13,
#   'SystemTime': '2020-09-20T21:22:24.799192Z',
#   'Computer': 'MSEDGEWIN10',
#   'UserID': 'S-1-5-18',
#   'ProcessGuid': '747F3D96-C6C1-5F67-0000-0010A65D0000',
#   'ProcessId': 648,
#   'Image': 'C:\\Windows\\system32\\lsass.exe',
#   'TargetObject': 'HKLM\\SAM\\SAM\\Domains\\Account\\Users\\000001F4\\ForcePasswordReset',
#   'Details': 'Binary Data'},
#  {'EventID': 10,
#   'SystemTime': '2020-07-07T21:51:39.262862Z',
#   'Computer': 'LAPTOP-JU4M3I0E',
#   'UserID': 'S-1-5-18',
#   'SourceProcessGuid': [],
#   'SourceProcessId': 28528,
#   'SourceThreadId': 22356,
#   'SourceImage': 'C:\\Users\\Public\\tools\\SysinternalsSuite\\procdump64.exe',
#   'TargetProcessGuid': [],
#   'TargetProcessId': 30096,
#   'TargetImage': 'C:\\windows\\system32\\lsass.exe',
#   'GrantedAccess': '0x1fffff',
#   'CallTrace': 'C:\\windows\\SYSTEM32\\ntdll.dll+9ca14|C:\\windows\\SYSTEM32\\ntdll.dll+110610|C:\\windows\\System32\\KERNELBASE.dll+d68de|C:\\Users\\Public\\tools\\SysinternalsSuite\\procdump64.exe+120bb|C:\\windows\\System32\\KERNEL32.DLL+17bd4|C:\\windows\\SYSTEM32\\ntdll.dll+6ce51'},
#  {'EventID': 10,
#   'SystemTime': '2020-07-07T21:51:39.256632Z',
#   'Computer': 'LAPTOP-JU4M3I0E',
#   'UserID': 'S-1-5-18',
#   'SourceProcessGuid': [],
#   'SourceProcessId': 28528,
#   'SourceThreadId': 3444,
#   'SourceImage': 'C:\\Users\\Public\\tools\\SysinternalsSuite\\procdump64.exe',
#   'TargetProcessGuid': [],
#   'TargetProcessId': 908,
#   'TargetImage': 'C:\\windows\\system32\\lsass.exe',
#   'GrantedAccess': '0x1fffff',
#   'CallTrace': 'C:\\windows\\SYSTEM32\\ntdll.dll+9c534|C:\\windows\\System32\\KERNELBASE.dll+2726e|C:\\Users\\Public\\tools\\SysinternalsSuite\\procdump64.exe+82b4|C:\\windows\\System32\\KERNEL32.DLL+17bd4|C:\\windows\\SYSTEM32\\ntdll.dll+6ce51'},
#  {'EventID': 10,
#   'SystemTime': '2020-07-07T21:51:39.204637Z',
#   'Computer': 'LAPTOP-JU4M3I0E',
#   'UserID': 'S-1-5-18',
#   'SourceProcessGuid': [],
#   'SourceProcessId': 30256,
#   'SourceThreadId': 5576,
#   'SourceImage': 'C:\\Users\\Public\\tools\\SysinternalsSuite\\procdump.exe',
#   'TargetProcessGuid': [],
#   'TargetProcessId': 908,
#   'TargetImage': 'C:\\windows\\system32\\lsass.exe',
#   'GrantedAccess': '0x1fffff',
#   'CallTrace': 'C:\\windows\\SYSTEM32\\ntdll.dll+9c534|C:\\windows\\System32\\wow64.dll+ba94|C:\\windows\\System32\\wow64.dll+7123|C:\\windows\\System32\\wow64cpu.dll+1783|C:\\windows\\System32\\wow64cpu.dll+1199|C:\\windows\\System32\\wow64.dll+c77a|C:\\windows\\System32\\wow64.dll+c637|C:\\windows\\SYSTEM32\\ntdll.dll+718eb|C:\\windows\\SYSTEM32\\ntdll.dll+717d3|C:\\windows\\SYSTEM32\\ntdll.dll+7177e|C:\\windows\\SYSTEM32\\ntdll.dll+7208c(wow64)|C:\\windows\\System32\\KERNELBASE.dll+f10a8(wow64)|C:\\Users\\Public\\tools\\SysinternalsSuite\\procdump.exe+7c36|C:\\windows\\System32\\KERNEL32.DLL+16359(wow64)|C:\\windows\\SYSTEM32\\ntdll.dll+67c24(wow64)|C:\\windows\\SYSTEM32\\ntdll.dll+67bf4(wow64)'},
#  {'EventID': 10,
#   'SystemTime': '2019-05-02T14:50:17.955524Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'SourceProcessGuid': [],
#   'SourceProcessId': 1508,
#   'SourceThreadId': 3204,
#   'SourceImage': 'C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe',
#   'TargetProcessGuid': [],
#   'TargetProcessId': 484,
#   'TargetImage': 'C:\\Windows\\system32\\lsass.exe',
#   'GrantedAccess': '0x143a',
#   'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+4595c|C:\\Windows\\system32\\KERNELBASE.dll+8185'},
#  {'EventID': 3,
#   'SystemTime': '2019-05-02T14:48:53.950750Z',
#   'Computer': 'IEWIN7',
#   'UserID': 'S-1-5-18',
#   'ProcessGuid': '365ABB72-0244-5CCB-0000-00109AE70B00',
#   'ProcessId': 1508,
#   'Image': 'C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe'},
#  {'EventID': 11,
#   'SystemTime': '2020-09-28T12:47:36.630448Z',
#   'Computer': 'DESKTOP-PIU87N6',
#   'UserID': 'S-1-5-18',
#   'ProcessGuid': 'BC47D85C-DB68-5F71-0000-0010B237AB01',
#   'ProcessId': 3352,
#   'TargetFilename': 'C:\\Users\\wanwan\\Desktop\\minidump_668.dmp',
#   'Image': 'C:\\WINDOWS\\system32\\rdrleakdiag.exe',
#   'CreationUtcTime': '2020-09-28 12:47:36.624'},
#  {'EventID': 1,
#   'SystemTime': '2020-09-28T12:47:36.215504Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'DESKTOP-PIU87N6',
#   'Hashes': 'MD5=BBBA8CE22384213070D0B9511EA181C5,SHA256=C41F0ECA09CBCEC776E807522C048A9E7A2D92CC3B4ECCDE2F8F6C42536AD094,IMPHASH=09FDE88C65E2BC5F1F90E96B673C52B1',
#   'Image': 'C:\\Windows\\System32\\lsass.exe',
#   'ParentImage': 'C:\\Windows\\System32\\lsass.exe',
#   'CommandLine': 'C:\\WINDOWS\\system32\\lsass.exe',
#   'ParentCommandLine': 'C:\\WINDOWS\\system32\\lsass.exe',
#   'ProcessId': 7468,
#   'ParentProcessId': 668},
#  {'EventID': 8,
#   'SystemTime': '2020-09-28T12:47:36.206545Z',
#   'Computer': 'DESKTOP-PIU87N6',
#   'UserID': 'S-1-5-18',
#   'SourceProcessGuid': 'BC47D85C-DB68-5F71-0000-0010B237AB01',
#   'SourceProcessId': 3352,
#   'TargetProcessGuid': 'BC47D85C-FAA9-5F68-0000-0010D9590000',
#   'TargetProcessId': 668,
#   'SourceImage': 'C:\\Windows\\System32\\rdrleakdiag.exe',
#   'TargetImage': 'C:\\Windows\\System32\\lsass.exe',
#   'NewThreadId': 3468,
#   'StartAddress': '0x00007FF8C72C5EC0',
#   'StartModule': 'C:\\WINDOWS\\SYSTEM32\\ntdll.dll',
#   'StartFunction': ''},
#  {'EventID': 1,
#   'SystemTime': '2020-09-28T12:47:36.197943Z',
#   'UserID': 'S-1-5-18',
#   'Computer': 'DESKTOP-PIU87N6',
#   'Hashes': 'MD5=C04F4FB2C7B44E19E85908459D3F0085,SHA256=D66E1EE7970598A5F34FD4B468B5B7705219E80A8A2784E7B18564831FCA797C,IMPHASH=5D87ACDE58B6E042FB38FE42B86E9C25',
#   'Image': 'C:\\Windows\\System32\\rdrleakdiag.exe',
#   'ParentImage': 'C:\\Windows\\System32\\cmd.exe',
#   'CommandLine': 'rdrleakdiag.exe  /p 668 /o C:\\Users\\wanwan\\Desktop /fullmemdmp /snap',
#   'ParentCommandLine': '"C:\\WINDOWS\\system32\\cmd.exe" ',
#   'ProcessId': 3352,
#   'ParentProcessId': 1456},
#  {'EventID': 4624,
#   'SystemTime': '2020-09-15T19:31:34.954809Z',
#   'SubjectUserSid': 'S-1-0-0',
#   'SubjectUserName': '-',
#   'SubjectDomainName': '-',
#   'SubjectLogonId': '0x0',
#   'TargetUserSid': 'S-1-5-18',
#   'TargetUserName': '01566S-WIN16-IR$',
#   'TargetDomainName': 'THREEBEESCO.COM',
#   'TargetLogonId': '0x32a0d3',
#   'LogonType': 3,
#   'LogonProcessName': 'Kerberos',
#   'WorkstationName': '-',
#   'TransmittedServices': '-',
#   'ProcessId': '0x0',
#   'ProcessName': '-',
#   'IpAddress': '::1',
#   'IpPort': '50441',
#   'TargetOutboundUserName': '-',
#   'TargetOutboundDomainName': '-'},
#  {'EventID': 4624,
#   'SystemTime': '2020-09-15T19:31:32.206739Z',
#   'SubjectUserSid': 'S-1-0-0',
#   'SubjectUserName': '-',
#   'SubjectDomainName': '-',
#   'SubjectLogonId': '0x0',
#   'TargetUserSid': 'S-1-5-18',
#   'TargetUserName': '01566S-WIN16-IR$',
#   'TargetDomainName': 'THREEBEESCO.COM',
#   'TargetLogonId': '0x329baa',
#   'LogonType': 3,
#   'LogonProcessName': 'Kerberos',
#   'WorkstationName': '-',
#   'TransmittedServices': '-',
#   'ProcessId': '0x0',
#   'ProcessName': '-',
#   'IpAddress': '::1',
#   'IpPort': '50443',
#   'TargetOutboundUserName': '-',
#   'TargetOutboundDomainName': '-'},
#  {'EventID': 4624,
#   'SystemTime': '2020-09-15T19:30:32.190369Z',
#   'SubjectUserSid': 'S-1-0-0',
#   'SubjectUserName': '-',
#   'SubjectDomainName': '-',
#   'SubjectLogonId': '0x0',
#   'TargetUserSid': 'S-1-5-18',
#   'TargetUserName': '01566S-WIN16-IR$',
#   'TargetDomainName': 'THREEBEESCO.COM',
#   'TargetLogonId': '0x320935',
#   'LogonType': 3,
#   'LogonProcessName': 'Kerberos',
#   'WorkstationName': '-',
#   'TransmittedServices': '-',
#   'ProcessId': '0x0',
#   'ProcessName': '-',
#   'IpAddress': '::1',
#   'IpPort': '50438',
#   'TargetOutboundUserName': '-',
#   'TargetOutboundDomainName': '-'},
#  {'EventID': 4624,
#   'SystemTime': '2020-09-15T19:29:51.517594Z',
#   'SubjectUserSid': 'S-1-0-0',
#   'SubjectUserName': '-',
#   'SubjectDomainName': '-',
#   'SubjectLogonId': '0x0',
#   'TargetUserSid': 'S-1-5-7',
#   'TargetUserName': 'ANONYMOUS LOGON',
#   'TargetDomainName': 'NT AUTHORITY',
#   'TargetLogonId': '0x31ff89',
#   'LogonType': 3,
#   'LogonProcessName': 'NtLmSsp ',
#   'WorkstationName': '02694W-WIN10',
#   'TransmittedServices': '-',
#   'ProcessId': '0x0',
#   'ProcessName': '-',
#   'IpAddress': '172.16.66.37',
#   'IpPort': '49707',
#   'TargetOutboundUserName': '-',
#   'TargetOutboundDomainName': '-'},
#  {'EventID': 4624,
#   'SystemTime': '2020-09-15T19:29:51.507713Z',
#   'SubjectUserSid': 'S-1-0-0',
#   'SubjectUserName': '-',
#   'SubjectDomainName': '-',
#   'SubjectLogonId': '0x0',
#   'TargetUserSid': 'S-1-5-7',
#   'TargetUserName': 'ANONYMOUS LOGON',
#   'TargetDomainName': 'NT AUTHORITY',
#   'TargetLogonId': '0x31ff6e',
#   'LogonType': 3,
#   'LogonProcessName': 'NtLmSsp ',
#   'WorkstationName': '02694W-WIN10',
#   'TransmittedServices': '-',
#   'ProcessId': '0x0',
#   'ProcessName': '-',
#   'IpAddress': '172.16.66.37',
#   'IpPort': '49707',
#   'TargetOutboundUserName': '-',
#   'TargetOutboundDomainName': '-'},
#  {'EventID': 4624,
#   'SystemTime': '2020-09-15T19:29:32.174941Z',
#   'SubjectUserSid': 'S-1-0-0',
#   'SubjectUserName': '-',
#   'SubjectDomainName': '-',
#   'SubjectLogonId': '0x0',
#   'TargetUserSid': 'S-1-5-18',
#   'TargetUserName': '01566S-WIN16-IR$',
#   'TargetDomainName': 'THREEBEESCO.COM',
#   'TargetLogonId': '0x31fb1a',
#   'LogonType': 3,
#   'LogonProcessName': 'Kerberos',
#   'WorkstationName': '-',
#   'TransmittedServices': '-',
#   'ProcessId': '0x0',
#   'ProcessName': '-',
#   'IpAddress': '::1',
#   'IpPort': '50437',
#   'TargetOutboundUserName': '-',
#   'TargetOutboundDomainName': '-'},
#  {'EventID': 4624,
#   'SystemTime': '2020-09-15T19:28:32.159991Z',
#   'SubjectUserSid': 'S-1-0-0',
#   'SubjectUserName': '-',
#   'SubjectDomainName': '-',
#   'SubjectLogonId': '0x0',
#   'TargetUserSid': 'S-1-5-18',
#   'TargetUserName': '01566S-WIN16-IR$',
#   'TargetDomainName': 'THREEBEESCO.COM',
#   'TargetLogonId': '0x31daf6',
#   'LogonType': 3,
#   'LogonProcessName': 'Kerberos',
#   'WorkstationName': '-',
#   'TransmittedServices': '-',
#   'ProcessId': '0x0',
#   'ProcessName': '-',
#   'IpAddress': '::1',
#   'IpPort': '50436',
#   'TargetOutboundUserName': '-',
#   'TargetOutboundDomainName': '-'}]

# %%
#Load event transformer lookup file to dict
mitrefile = open('./mitre_winevent_lookup.json',) 
mitrelookup = json.load(mitrefile)
mitrelookup
# Out:
# [{'EventID': [4688, 4663],
#   'Tactic': 'Collection',
#   'TechniqueName': 'Audio Capture',
#   'TechniqueID': 'T1123'},
#  {'EventID': [4688, 4663],
#   'Tactic': 'Collection',
#   'TechniqueName': 'Automated Collection',
#   'TechniqueID': 'T1119'},
#  {'EventID': [4688, 4688, 200, 4663, 5861, 500, 4100, 4104],
#   'Tactic': 'Collection',
#   'TechniqueName': 'Data from Local System',
#   'TechniqueID': 'T1005'},
#  {'EventID': [4688, 4688, 5140, 4663, 5145],
#   'Tactic': 'Collection',
#   'TechniqueName': 'Data from Network Shared Drive',
#   'TechniqueID': 'T1039'},
#  {'EventID': [4688, 4688, 4657, 4663, 5140, 5145],
#   'Tactic': 'Collection',
#   'TechniqueName': 'Data from Removable Media',
#   'TechniqueID': 'T1025'},
#  {'EventID': [4688, 4688, 4663],
#   'Tactic': 'Collection',
#   'TechniqueName': 'Data Staged',
#   'TechniqueID': 'T1074'},
#  {'EventID': [4688, 5156, 4624, 4663],
#   'Tactic': 'Collection',
#   'TechniqueName': 'Email Collection',
#   'TechniqueID': 'T1114'},
#  {'EventID': [4624, 4688],
#   'Tactic': 'Collection',
#   'TechniqueName': 'Man in the Browser',
#   'TechniqueID': 'T1185'},
#  {'EventID': [4688, 4663],
#   'Tactic': 'Collection',
#   'TechniqueName': 'Screen Capture',
#   'TechniqueID': 'T1113'},
#  {'EventID': [4688, 4663],
#   'Tactic': 'Collection',
#   'TechniqueName': 'Video Capture',
#   'TechniqueID': 'T1125'},
#  {'EventID': [4657, 4688],
#   'Tactic': 'Collection,Credential Access',
#   'TechniqueName': 'Input Capture',
#   'TechniqueID': 'T1056'},
#  {'EventID': [5156, 4688],
#   'Tactic': 'Command and Control',
#   'TechniqueName': 'Commonly Used Port',
#   'TechniqueID': 'T1043'},
#  {'EventID': [4657, 4663],
#   'Tactic': 'Command and Control',
#   'TechniqueName': 'Communication Through Removable Media',
#   'TechniqueID': 'T1092'},
#  {'EventID': [5156, 4688],
#   'Tactic': 'Command and Control',
#   'TechniqueName': 'Connection Proxy',
#   'TechniqueID': 'T1090'},
#  {'EventID': [5156, 4688],
#   'Tactic': 'Command and Control',
#   'TechniqueName': 'Custom Command and Control Protocol',
#   'TechniqueID': 'T1094'},
#  {'EventID': [4688, 4688, 5156],
#   'Tactic': 'Command and Control',
#   'TechniqueName': 'Custom Cryptographic Protocol',
#   'TechniqueID': 'T1024'},
#  {'EventID': [5156, 4688],
#   'Tactic': 'Command and Control',
#   'TechniqueName': 'Data Encoding',
#   'TechniqueID': 'T1132'},
#  {'EventID': [4688, 5156],
#   'Tactic': 'Command and Control',
#   'TechniqueName': 'Data Obfuscation',
#   'TechniqueID': 'T1001'},
#  {'EventID': [4688, 5156],
#   'Tactic': 'Command and Control',
#   'TechniqueName': 'Fallback Channels',
#   'TechniqueID': 'T1008'},
#  {'EventID': [4688, 4688, 5156],
#   'Tactic': 'Command and Control',
#   'TechniqueName': 'Multiband Communication',
#   'TechniqueID': 'T1026'},
#  {'EventID': [5156, 4688],
#   'Tactic': 'Command and Control',
#   'TechniqueName': 'Multilayer Encryption',
#   'TechniqueID': 'T1079'},
#  {'EventID': [5156],
#   'Tactic': 'Command and Control',
#   'TechniqueName': 'Multi-Stage Channels',
#   'TechniqueID': 'T1104'},
#  {'EventID': [5156, 4688],
#   'Tactic': 'Command and Control',
#   'TechniqueName': 'Remote Access Tools',
#   'TechniqueID': 'T1219'},
#  {'EventID': [5156, 4688],
#   'Tactic': 'Command and Control',
#   'TechniqueName': 'Standard Application Layer Protocol',
#   'TechniqueID': 'T1071'},
#  {'EventID': [5156, 4688],
#   'Tactic': 'Command and Control',
#   'TechniqueName': 'Standard Cryptographic Protocol',
#   'TechniqueID': 'T1032'},
#  {'EventID': [5156, 4688],
#   'Tactic': 'Command and Control',
#   'TechniqueName': 'Standard Non-Application Layer Protocol',
#   'TechniqueID': 'T1095'},
#  {'EventID': [5156, 4688],
#   'Tactic': 'Command and Control',
#   'TechniqueName': 'Uncommonly Used Port',
#   'TechniqueID': 'T1065'},
#  {'EventID': [4663, 5156, 4688],
#   'Tactic': 'Command and Control,Lateral Movement',
#   'TechniqueName': 'Remote File Copy',
#   'TechniqueID': 'T1105'},
#  {'EventID': [4624],
#   'Tactic': 'Credential Access',
#   'TechniqueName': 'Account Manipulation',
#   'TechniqueID': 'T1098'},
#  {'EventID': [4624],
#   'Tactic': 'Credential Access',
#   'TechniqueName': 'Brute Force',
#   'TechniqueID': 'T1110'},
#  {'EventID': [4688, 4688, 200, 500, 4100, 4104],
#   'Tactic': 'Credential Access',
#   'TechniqueName': 'Credential Dumping',
#   'TechniqueID': 'T1003'},
#  {'EventID': [4663, 4688],
#   'Tactic': 'Credential Access',
#   'TechniqueName': 'Credentials in Files',
#   'TechniqueID': 'T1081'},
#  {'EventID': [4657, 4688, 4688],
#   'Tactic': 'Credential Access',
#   'TechniqueName': 'Credentials in Registry',
#   'TechniqueID': 'T1214'},
#  {'EventID': [4624, 4688, 1000, 1001],
#   'Tactic': 'Credential Access',
#   'TechniqueName': 'Exploitation for Credential Access',
#   'TechniqueID': 'T1212'},
#  {'EventID': [5156, 4663],
#   'Tactic': 'Credential Access',
#   'TechniqueName': 'Forced Authentication',
#   'TechniqueID': 'T1187'},
#  {'EventID': [4769],
#   'Tactic': 'Credential Access',
#   'TechniqueName': 'Kerberoasting',
#   'TechniqueID': 'T1208'},
#  {'EventID': [4657, 5156],
#   'Tactic': 'Credential Access',
#   'TechniqueName': 'LLMNR/NBT-NS Poisoning',
#   'TechniqueID': 'T1171'},
#  {'EventID': [4688, 4657],
#   'Tactic': 'Credential Access',
#   'TechniqueName': 'Password Filter DLL',
#   'TechniqueID': 'T1174'},
#  {'EventID': [4657],
#   'Tactic': 'Credential Access',
#   'TechniqueName': 'Private Keys',
#   'TechniqueID': 'T1145'},
#  {'EventID': [4688, 7, 7],
#   'Tactic': 'Credential Access,Persistence,Privilege Escalation',
#   'TechniqueName': 'Hooking',
#   'TechniqueID': 'T1179'},
#  {'EventID': [4688, 4688, 4663],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'Binary Padding',
#   'TechniqueID': 'T1009'},
#  {'EventID': [4624],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'DCShadow',
#   'TechniqueID': 'T1207'},
#  {'EventID': [4688, 4688, 4663],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'Deobfuscate/Decode Files or Information',
#   'TechniqueID': 'T1140'},
#  {'EventID': [4688, 4689, 4657, 4663, 7040],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'Disabling Security Tools',
#   'TechniqueID': 'T1089'},
#  {'EventID': [5156, 4688, 7],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'DLL Side-Loading',
#   'TechniqueID': 'T1073'},
#  {'EventID': [4688, 4663, 1000, 1001],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'Exploitation for Defense Evasion',
#   'TechniqueID': 'T1211'},
#  {'EventID': [4688, 4663, 9],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'File Deletion',
#   'TechniqueID': 'T1107'},
#  {'EventID': [4688, 4688, 200, 4663, 500, 4100, 4104],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'File System Logical Offsets',
#   'TechniqueID': 'T1006'},
#  {'EventID': [4688, 4688],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'Indicator Blocking',
#   'TechniqueID': 'T1054'},
#  {'EventID': [4688, 4688, 5156, 9],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'Indicator Removal from Tools',
#   'TechniqueID': 'T1066'},
#  {'EventID': [4663, 4688, 4688],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'Indicator Removal on Host',
#   'TechniqueID': 'T1070'},
#  {'EventID': [4688, 4688, 1, 7],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'Indirect Command Execution',
#   'TechniqueID': 'T1202'},
#  {'EventID': [4657],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'Install Root Certificate',
#   'TechniqueID': 'T1130'},
#  {'EventID': [4688, 4663, 9],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'Masquerading',
#   'TechniqueID': 'T1036'},
#  {'EventID': [4657, 4663, 4688, 4688],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'Modify Registry',
#   'TechniqueID': 'T1112'},
#  {'EventID': [4688, 4688, 5140, 4624, 5145],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'Network Share Connection Removal',
#   'TechniqueID': 'T1126'},
#  {'EventID': [4663],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'NTFS File Attributes',
#   'TechniqueID': 'T1096'},
#  {'EventID': [5156, 4688, 4663],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'Obfuscated Files or Information',
#   'TechniqueID': 'T1027'},
#  {'EventID': [4688],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'Process Doppelg?nging',
#   'TechniqueID': 'T1186'},
#  {'EventID': [4688, 9],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'Process Hollowing',
#   'TechniqueID': 'T1093'},
#  {'EventID': [4688],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'Rootkit',
#   'TechniqueID': 'T1014'},
#  {'EventID': [9],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'Software Packing',
#   'TechniqueID': 'T1045'},
#  {'EventID': [4688, 4688, 4663],
#   'Tactic': 'Defense Evasion',
#   'TechniqueName': 'Timestomp',
#   'TechniqueID': 'T1099'},
#  {'EventID': [4688, 4688],
#   'Tactic': 'Defense Evasion,Execution',
#   'TechniqueName': 'CMSTP',
#   'TechniqueID': 'T1191'},
#  {'EventID': [4688, 4688, 4657],
#   'Tactic': 'Defense Evasion,Execution',
#   'TechniqueName': 'Control Panel Items',
#   'TechniqueID': 'T1196'},
#  {'EventID': [4688, 4688, 1, 7],
#   'Tactic': 'Defense Evasion,Execution',
#   'TechniqueName': 'InstallUtil',
#   'TechniqueID': 'T1118'},
#  {'EventID': [4688, 4688, 1, 7],
#   'Tactic': 'Defense Evasion,Execution',
#   'TechniqueName': 'Mshta',
#   'TechniqueID': 'T1170'},
#  {'EventID': [4688, 4688, 1, 7],
#   'Tactic': 'Defense Evasion,Execution',
#   'TechniqueName': 'Regsvcs/Regasm',
#   'TechniqueID': 'T1121'},
#  {'EventID': [4688, 4688, 7, 4657],
#   'Tactic': 'Defense Evasion,Execution',
#   'TechniqueName': 'Regsvr32',
#   'TechniqueID': 'T1117'},
#  {'EventID': [4688, 4688, 4663],
#   'Tactic': 'Defense Evasion,Execution',
#   'TechniqueName': 'Rundll32',
#   'TechniqueID': 'T1085'},
#  {'EventID': [4688, 4688, 4663],
#   'Tactic': 'Defense Evasion,Execution',
#   'TechniqueName': 'Scripting',
#   'TechniqueID': 'T1064'},
#  {'EventID': [4688, 4688],
#   'Tactic': 'Defense Evasion,Execution',
#   'TechniqueName': 'Signed Binary Proxy Execution',
#   'TechniqueID': 'T1218'},
#  {'EventID': [4688, 4688],
#   'Tactic': 'Defense Evasion,Execution',
#   'TechniqueName': 'Signed Script Proxy Execution',
#   'TechniqueID': 'T1216'},
#  {'EventID': [4688, 4688],
#   'Tactic': 'Defense Evasion,Execution',
#   'TechniqueName': 'Trusted Developer Utilities',
#   'TechniqueID': 'T1127'},
#  {'EventID': [4688],
#   'Tactic': 'Defense Evasion,Persistence',
#   'TechniqueName': 'BITS Jobs',
#   'TechniqueID': 'T1197'},
#  {'EventID': [4688, 4663],
#   'Tactic': 'Defense Evasion,Persistence',
#   'TechniqueName': 'Component Firmware',
#   'TechniqueID': 'T1109'},
#  {'EventID': [4688],
#   'Tactic': 'Defense Evasion,Persistence',
#   'TechniqueName': 'Component Object Model Hijacking',
#   'TechniqueID': 'T1122'},
#  {'EventID': [4663, 4688, 4688],
#   'Tactic': 'Defense Evasion,Persistence',
#   'TechniqueName': 'Hidden Files and Directories',
#   'TechniqueID': 'T1158'},
#  {'EventID': [4688, 5156, 4663, 4624, 9],
#   'Tactic': 'Defense Evasion,Persistence',
#   'TechniqueName': 'Redundant Access',
#   'TechniqueID': 'T1108'},
#  {'EventID': [4688, 4657],
#   'Tactic': 'Defense Evasion,Persistence',
#   'TechniqueName': 'SIP and Trust Provider Hijacking',
#   'TechniqueID': 'T1198'},
#  {'EventID': [4688, 4688, 4663, 7],
#   'Tactic': 'Defense Evasion,Persistence,Privilege Escalation',
#   'TechniqueName': 'DLL Search Order Hijacking',
#   'TechniqueID': 'T1038'},
#  {'EventID': [4688, 4657, 0],
#   'Tactic': 'Defense Evasion,Persistence,Privilege Escalation',
#   'TechniqueName': 'Image File Execution Options Injection',
#   'TechniqueID': 'T1183'},
#  {'EventID': [4624, 4688],
#   'Tactic': 'Defense Evasion,Persistence,Privilege Escalation,Initial Access',
#   'TechniqueName': 'Valid Accounts',
#   'TechniqueID': 'T1078'},
#  {'EventID': [4688],
#   'Tactic': 'Defense Evasion,Privilege Escalation',
#   'TechniqueName': 'Access Token Manipulation',
#   'TechniqueID': 'T1134'},
#  {'EventID': [4688, 4688, 4624],
#   'Tactic': 'Defense Evasion,Privilege Escalation',
#   'TechniqueName': 'Bypass User Account Control',
#   'TechniqueID': 'T1088'},
#  {'EventID': [4657, 4663, 4688],
#   'Tactic': 'Defense Evasion,Privilege Escalation',
#   'TechniqueName': 'Process Injection',
#   'TechniqueID': 'T1055'},
#  {'EventID': [4688, 4688],
#   'Tactic': 'Discovery',
#   'TechniqueName': 'Account Discovery',
#   'TechniqueID': 'T1087'},
#  {'EventID': [4688, 4688],
#   'Tactic': 'Discovery',
#   'TechniqueName': 'Application Window Discovery',
#   'TechniqueID': 'T1010'},
#  {'EventID': [4663, 4688, 4688],
#   'Tactic': 'Discovery',
#   'TechniqueName': 'Browser Bookmark Discovery',
#   'TechniqueID': 'T1217'},
#  {'EventID': [4663, 4688, 4688],
#   'Tactic': 'Discovery',
#   'TechniqueName': 'File and Directory Discovery',
#   'TechniqueID': 'T1083'},
#  {'EventID': [4688, 5156],
#   'Tactic': 'Discovery',
#   'TechniqueName': 'Network Service Scanning',
#   'TechniqueID': 'T1046'},
#  {'EventID': [4688, 4688, 5156, 5140, 5145],
#   'Tactic': 'Discovery',
#   'TechniqueName': 'Network Share Discovery',
#   'TechniqueID': 'T1135'},
#  {'EventID': [4688, 4688],
#   'Tactic': 'Discovery',
#   'TechniqueName': 'Password Policy Discovery',
#   'TechniqueID': 'T1201'},
#  {'EventID': [4688, 4688],
#   'Tactic': 'Discovery',
#   'TechniqueName': 'Peripheral Device Discovery',
#   'TechniqueID': 'T1120'},
#  {'EventID': [4688, 4688],
#   'Tactic': 'Discovery',
#   'TechniqueName': 'Permission Groups Discovery',
#   'TechniqueID': 'T1069'},
#  {'EventID': [4688, 4688],
#   'Tactic': 'Discovery',
#   'TechniqueName': 'Process Discovery',
#   'TechniqueID': 'T1057'},
#  {'EventID': [4688, 4688],
#   'Tactic': 'Discovery',
#   'TechniqueName': 'Query Registry',
#   'TechniqueID': 'T1012'},
#  {'EventID': [4688, 4688, 5156],
#   'Tactic': 'Discovery',
#   'TechniqueName': 'Remote System Discovery',
#   'TechniqueID': 'T1018'},
#  {'EventID': [4663, 4688, 4688],
#   'Tactic': 'Discovery',
#   'TechniqueName': 'Security Software Discovery',
#   'TechniqueID': 'T1063'},
#  {'EventID': [4688, 4688],
#   'Tactic': 'Discovery',
#   'TechniqueName': 'System Information Discovery',
#   'TechniqueID': 'T1082'},
#  {'EventID': [4688, 4688, 200, 5861, 500, 4100, 4104],
#   'Tactic': 'Discovery',
#   'TechniqueName': 'System Network Configuration Discovery',
#   'TechniqueID': 'T1016'},
#  {'EventID': [4688, 4688],
#   'Tactic': 'Discovery',
#   'TechniqueName': 'System Network Connections Discovery',
#   'TechniqueID': 'T1049'},
#  {'EventID': [4688, 4688, 4663, 4624],
#   'Tactic': 'Discovery',
#   'TechniqueName': 'System Owner/User Discovery',
#   'TechniqueID': 'T1033'},
#  {'EventID': [4688, 4688, 5861],
#   'Tactic': 'Discovery',
#   'TechniqueName': 'System Service Discovery',
#   'TechniqueID': 'T1007'},
#  {'EventID': [4688, 4688],
#   'Tactic': 'Discovery',
#   'TechniqueName': 'System Time Discovery',
#   'TechniqueID': 'T1124'},
#  {'EventID': [4688, 4688],
#   'Tactic': 'Execution',
#   'TechniqueName': 'Command-Line Interface',
#   'TechniqueID': 'T1059'},
#  {'EventID': [4688, 4657],
#   'Tactic': 'Execution',
#   'TechniqueName': 'Dynamic Data Exchange',
#   'TechniqueID': 'T1173'},
#  {'EventID': [4688],
#   'Tactic': 'Execution',
#   'TechniqueName': 'Execution through API',
#   'TechniqueID': 'T1106'},
#  {'EventID': [4688, 4663],
#   'Tactic': 'Execution',
#   'TechniqueName': 'Execution through Module Load',
#   'TechniqueID': 'T1129'},
#  {'EventID': [4688, 5156],
#   'Tactic': 'Execution',
#   'TechniqueName': 'Exploitation for Client Execution',
#   'TechniqueID': 'T1203'},
#  {'EventID': [4688, 4688, 4663, 9],
#   'Tactic': 'Execution',
#   'TechniqueName': 'Graphical User Interface',
#   'TechniqueID': 'T1061'},
#  {'EventID': [4688, 4688, 4657, 4663],
#   'Tactic': 'Execution',
#   'TechniqueName': 'PowerShell',
#   'TechniqueID': 'T1086'},
#  {'EventID': [4688, 4688, 4657, 7045, 7040],
#   'Tactic': 'Execution',
#   'TechniqueName': 'Service Execution',
#   'TechniqueID': 'T1035'},
#  {'EventID': [4688, 4688],
#   'Tactic': 'Execution',
#   'TechniqueName': 'User Execution',
#   'TechniqueID': 'T1204'},
#  {'EventID': [4688, 4688, 4624],
#   'Tactic': 'Execution',
#   'TechniqueName': 'Windows Management Instrumentation',
#   'TechniqueID': 'T1047'},
#  {'EventID': [4688, 5156, 4663, 4657],
#   'Tactic': 'Execution,Lateral Movement',
#   'TechniqueName': 'Third-party Software',
#   'TechniqueID': 'T1072'},
#  {'EventID': [4688, 4688, 5156, 5140, 4663, 4624, 5145],
#   'Tactic': 'Execution,Lateral Movement',
#   'TechniqueName': 'Windows Remote Management',
#   'TechniqueID': 'T1028'},
#  {'EventID': [4688, 4663],
#   'Tactic': 'Execution,Persistence',
#   'TechniqueName': 'LSASS Driver',
#   'TechniqueID': 'T1177'},
#  {'EventID': [4688, 4688, 4663],
#   'Tactic': 'Execution,Persistence,Privilege Escalation',
#   'TechniqueName': 'Scheduled Task',
#   'TechniqueID': 'T1053'},
#  {'EventID': [4688, 4688, 5156, 4663],
#   'Tactic': 'Exfiltration',
#   'TechniqueName': 'Automated Exfiltration',
#   'TechniqueID': 'T1020'},
#  {'EventID': [4688, 4688, 4663, 5156],
#   'Tactic': 'Exfiltration',
#   'TechniqueName': 'Data Compressed',
#   'TechniqueID': 'T1002'},
#  {'EventID': [4688, 4688, 4663],
#   'Tactic': 'Exfiltration',
#   'TechniqueName': 'Data Encrypted',
#   'TechniqueID': 'T1022'},
#  {'EventID': [5156, 4688],
#   'Tactic': 'Exfiltration',
#   'TechniqueName': 'Data Transfer Size Limits',
#   'TechniqueID': 'T1030'},
#  {'EventID': [4688, 5156],
#   'Tactic': 'Exfiltration',
#   'TechniqueName': 'Exfiltration Over Alternative Protocol',
#   'TechniqueID': 'T1048'},
#  {'EventID': [4688, 5156],
#   'Tactic': 'Exfiltration',
#   'TechniqueName': 'Exfiltration Over Command and Control Channel',
#   'TechniqueID': 'T1041'},
#  {'EventID': [4688, 4688, 5156],
#   'Tactic': 'Exfiltration',
#   'TechniqueName': 'Exfiltration Over Other Network Medium',
#   'TechniqueID': 'T1011'},
#  {'EventID': [4657, 219, 441],
#   'Tactic': 'Exfiltration',
#   'TechniqueName': 'Exfiltration Over Physical Medium',
#   'TechniqueID': 'T1052'},
#  {'EventID': [5156, 4688, 100, 200],
#   'Tactic': 'Exfiltration',
#   'TechniqueName': 'Scheduled Transfer',
#   'TechniqueID': 'T1029'},
#  {'EventID': [4688, 5156],
#   'Tactic': 'Initial Access',
#   'TechniqueName': 'Drive-by Compromise',
#   'TechniqueID': 'T1189'},
#  {'EventID': [4688, 4663],
#   'Tactic': 'Initial Access',
#   'TechniqueName': 'Spearphishing Attachment',
#   'TechniqueID': 'T1193'},
#  {'EventID': [4663],
#   'Tactic': 'Initial Access',
#   'TechniqueName': 'Supply Chain Compromise',
#   'TechniqueID': 'T1195'},
#  {'EventID': [4688, 4688, 5156, 4663],
#   'Tactic': 'Lateral Movement',
#   'TechniqueName': 'Application Deployment Software',
#   'TechniqueID': 'T1017'},
#  {'EventID': [4688, 4657],
#   'Tactic': 'Lateral Movement',
#   'TechniqueName': 'Distributed Component Object Model',
#   'TechniqueID': 'T1175'},
#  {'EventID': [4688, 4663, 1000, 1001],
#   'Tactic': 'Lateral Movement',
#   'TechniqueName': 'Exploitation of Remote Services',
#   'TechniqueID': 'T1210'},
#  {'EventID': [4624],
#   'Tactic': 'Lateral Movement',
#   'TechniqueName': 'Pass the Hash',
#   'TechniqueID': 'T1075'},
#  {'EventID': [4624],
#   'Tactic': 'Lateral Movement',
#   'TechniqueName': 'Pass the Ticket',
#   'TechniqueID': 'T1097'},
#  {'EventID': [4688, 4624],
#   'Tactic': 'Lateral Movement',
#   'TechniqueName': 'Remote Desktop Protocol',
#   'TechniqueID': 'T1076'},
#  {'EventID': [4624, 2123, 4625, 2541],
#   'Tactic': 'Lateral Movement',
#   'TechniqueName': 'Remote Services',
#   'TechniqueID': 'T1021'},
#  {'EventID': [4663, 4688],
#   'Tactic': 'Lateral Movement',
#   'TechniqueName': 'Shared Webroot',
#   'TechniqueID': 'T1051'},
#  {'EventID': [4663, 4688],
#   'Tactic': 'Lateral Movement',
#   'TechniqueName': 'Taint Shared Content',
#   'TechniqueID': 'T1080'},
#  {'EventID': [5156, 4624, 4688, 4688],
#   'Tactic': 'Lateral Movement',
#   'TechniqueName': 'Windows Admin Shares',
#   'TechniqueID': 'T1077'},
#  {'EventID': [219, 4657, 4663, 421, 4657],
#   'Tactic': 'Lateral Movement,Credential Access,Initial Access',
#   'TechniqueName': 'Replication Through Removable Media',
#   'TechniqueID': 'T1091'},
#  {'EventID': [4688, 4663],
#   'Tactic': 'Lateral Movement,Persistence',
#   'TechniqueName': 'Logon Scripts',
#   'TechniqueID': 'T1037'},
#  {'EventID': [4657],
#   'Tactic': 'Persistence',
#   'TechniqueName': 'Authentication Package',
#   'TechniqueID': 'T1131'},
#  {'EventID': [5156, 4688, 4663],
#   'Tactic': 'Persistence',
#   'TechniqueName': 'Browser Extensions',
#   'TechniqueID': 'T1176'},
#  {'EventID': [4657, 4688, 4688],
#   'Tactic': 'Persistence',
#   'TechniqueName': 'Change Default File Association',
#   'TechniqueID': 'T1042'},
#  {'EventID': [4688, 4688, 4624],
#   'Tactic': 'Persistence',
#   'TechniqueName': 'Create Account',
#   'TechniqueID': 'T1136'},
#  {'EventID': [4624],
#   'Tactic': 'Persistence',
#   'TechniqueName': 'External Remote Services',
#   'TechniqueID': 'T1133'},
#  {'EventID': [4688, 4688, 4657, 4663, 7040],
#   'Tactic': 'Persistence',
#   'TechniqueName': 'Modify Existing Service',
#   'TechniqueID': 'T1031'},
#  {'EventID': [4688, 4657],
#   'Tactic': 'Persistence',
#   'TechniqueName': 'Netsh Helper DLL',
#   'TechniqueID': 'T1128'},
#  {'EventID': [4688, 4688, 4657, 4663],
#   'Tactic': 'Persistence',
#   'TechniqueName': 'Office Application Startup',
#   'TechniqueID': 'T1137'},
#  {'EventID': [4657, 4663],
#   'Tactic': 'Persistence',
#   'TechniqueName': 'Registry Run Keys / Start Folder',
#   'TechniqueID': 'T1060'},
#  {'EventID': [4688, 4688, 4657, 4663],
#   'Tactic': 'Persistence',
#   'TechniqueName': 'Screensaver',
#   'TechniqueID': 'T1180'},
#  {'EventID': [4657],
#   'Tactic': 'Persistence',
#   'TechniqueName': 'Security Support Provider',
#   'TechniqueID': 'T1101'},
#  {'EventID': [4688, 4688, 4663],
#   'Tactic': 'Persistence',
#   'TechniqueName': 'Shortcut Modification',
#   'TechniqueID': 'T1023'},
#  {'EventID': [4688, 4663],
#   'Tactic': 'Persistence',
#   'TechniqueName': 'Time Providers',
#   'TechniqueID': 'T1209'},
#  {'EventID': [5861],
#   'Tactic': 'Persistence',
#   'TechniqueName': 'Windows Management Instrumentation Event Subscription',
#   'TechniqueID': 'T1084'},
#  {'EventID': [4688, 4657, 4663],
#   'Tactic': 'Persistence',
#   'TechniqueName': 'Winlogon Helper DLL',
#   'TechniqueID': 'T1004'},
#  {'EventID': [4688, 4657, 4663],
#   'Tactic': 'Persistence,Privilege Escalation',
#   'TechniqueName': 'Accessibility Features',
#   'TechniqueID': 'T1015'},
#  {'EventID': [4688, 4657],
#   'Tactic': 'Persistence,Privilege Escalation',
#   'TechniqueName': 'AppCert DLLs',
#   'TechniqueID': 'T1182'},
#  {'EventID': [4688, 4657],
#   'Tactic': 'Persistence,Privilege Escalation',
#   'TechniqueName': 'AppInit DLLs',
#   'TechniqueID': 'T1103'},
#  {'EventID': [4688, 4688, 4657],
#   'Tactic': 'Persistence,Privilege Escalation',
#   'TechniqueName': 'Application Shimming',
#   'TechniqueID': 'T1138'},
#  {'EventID': [4663, 4688, 7040, 7045],
#   'Tactic': 'Persistence,Privilege Escalation',
#   'TechniqueName': 'File System Permissions Weakness',
#   'TechniqueID': 'T1044'},
#  {'EventID': [4657, 4688, 4688],
#   'Tactic': 'Persistence,Privilege Escalation',
#   'TechniqueName': 'New Service',
#   'TechniqueID': 'T1050'},
#  {'EventID': [4688, 4663, 866, 8000, 8027],
#   'Tactic': 'Persistence,Privilege Escalation',
#   'TechniqueName': 'Path Interception',
#   'TechniqueID': 'T1034'},
#  {'EventID': [4688, 4657, 4663],
#   'Tactic': 'Persistence,Privilege Escalation',
#   'TechniqueName': 'Port Monitors',
#   'TechniqueID': 'T1013'},
#  {'EventID': [4688, 7040, 4657, 7045],
#   'Tactic': 'Persistence,Privilege Escalation',
#   'TechniqueName': 'Service Registry Permissions Weakness',
#   'TechniqueID': 'T1058'},
#  {'EventID': [4688, 4663, 4624, 4625],
#   'Tactic': 'Persistence,Privilege Escalation',
#   'TechniqueName': 'Web Shell',
#   'TechniqueID': 'T1100'},
#  {'EventID': [1000, 4688, 1001],
#   'Tactic': 'Privilege Escalation',
#   'TechniqueName': 'Exploitation for Privilege Escalation',
#   'TechniqueID': 'T1068'},
#  {'EventID': [4624, 4625],
#   'Tactic': 'Privilege Escalation',
#   'TechniqueName': 'SID-History Injection',
#   'TechniqueID': 'T1178'}]

# %%
from py2neo import Graph, Node, Relationship, NodeMatcher, cypher

graph = Graph(password="admin")
tx = graph.begin()
nodes = NodeMatcher(graph)

# %%
for item in jsonlist:
    if 'SubjectUserName' in item.keys():
        user_node1 = Node("User", name = item['SubjectUserName'])
        existing_event_node2 = nodes.match('Event', name=str(item['EventID'])).first()
        
        if existing_event_node2:
            
            existing_n1_created_n2 = Relationship(user_node1, 'created', existing_event_node2)
            graph.create(existing_n1_created_n2)
            print("done")
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
